# %%
from UNetPyTorch import *

import xarray as xr
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

from datetime import datetime

import cartopy
import cartopy.crs as ccrs

from torch.utils.data import DataLoader, Dataset

from IPython.display import HTML

ds = xr.open_dataset('data_850/2022_850_SA_coarsen.nc')
ds.load()
# Out:
# c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# <xarray.Dataset> Size: 197MB
# Dimensions:    (time: 8760, latitude: 16, longitude: 32)
# Coordinates:
#   * time       (time) datetime64[ns] 70kB 2022-01-01 ... 2022-12-31T23:00:00
#   * longitude  (longitude) float32 128B 16.31 16.81 17.31 ... 30.81 31.31 31.81
#   * latitude   (latitude) float32 64B -34.89 -34.39 -33.89 ... -27.89 -27.39
# Data variables:
#     q          (time, latitude, longitude) float64 36MB 0.007599 ... 0.009553
#     t          (time, latitude, longitude) float64 36MB 282.4 282.5 ... 284.3
#     u          (time, latitude, longitude) float64 36MB 14.09 13.71 ... 3.188
#     v          (time, latitude, longitude) float64 36MB -0.8432 -1.022 ... 4.144
#     w          (time, latitude, longitude) float64 36MB -0.002005 ... 0.1457
#     wspd       (time, latitude, longitude) float32 18MB 14.12 13.75 ... 5.228
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-05-28 12:36:03 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...
#     wspd_units:   m/s

# %% [markdown]
# ### Model

# %%
# Data shapes

# X_train shape: torch.Size([2317, 10, 16, 32])
# y_train shape: torch.Size([2317, 13, 16, 32])
# F_train shape: torch.Size([2317, 2])
# X_test shape: torch.Size([580, 10, 16, 32])
# y_test shape: torch.Size([580, 13, 16, 32])
# F_test shape: torch.Size([580, 2])

# Model input

# X shape: torch.Size([1, 10, 16, 32])
# F shape: torch.Size([1, 2])

# Model output

# y shape: torch.Size([1, 1, 16, 32])

class SimpleMLP(nn.Module):
    def __init__(self, input_size, forcing_size, output_size):
        super(SimpleMLP, self).__init__()
        # Define the MLP layers
        self.fc1 = nn.Linear(input_size + forcing_size, 128)  # Input layer with hidden layer of size 128
        self.fc2 = nn.Linear(128, 64)  # Hidden layer with 64 neurons
        self.fc3 = nn.Linear(64, output_size)  # Output layer

    def forward(self, X, F):
        # Flatten the spatial dimensions of X
        batch_size = X.size(0)
        X = X.view(batch_size, -1)  # Flatten to (batch_size, 10 * 16 * 32)

        # Concatenate the forcing data F
        inputs = torch.cat((X, F), dim=1)  # Shape: (batch_size, 10 * 16 * 32 + 2)

        # Pass through the MLP layers
        x = torch.relu(self.fc1(inputs))  # Activation function after first layer
        x = torch.relu(self.fc2(x))  # Activation function after second layer
        x = self.fc3(x)  # Output layer

        # Reshape the output to match the expected output shape
        return x.view(-1, 1, 16, 32)  # Shape: (batch_size, 1, 16, 32)

class LargerMLP(nn.Module):
    def __init__(self, input_size, forcing_size, output_size):
        super(LargerMLP, self).__init__()
        # Define the MLP layers with increased size and depth
        self.fc1 = nn.Linear(input_size + forcing_size, 256)  # First layer with 256 neurons
        self.fc2 = nn.Linear(256, 128)  # Second layer with 128 neurons
        self.fc3 = nn.Linear(128, 128)  # Third layer with 128 neurons
        self.fc4 = nn.Linear(128, 64)    # Fourth layer with 64 neurons
        self.fc5 = nn.Linear(64, output_size)  # Output layer

        # Optional: Adding dropout layers for regularization
        self.dropout = nn.Dropout(0.2)  # Dropout layer with a dropout probability of 0.2

    def forward(self, X, F):
        # Flatten the spatial dimensions of X
        batch_size = X.size(0)
        X = X.view(batch_size, -1)  # Flatten to (batch_size, 10 * 16 * 32)

        # Concatenate the forcing data F
        inputs = torch.cat((X, F), dim=1)  # Shape: (batch_size, 10 * 16 * 32 + 2)

        # Pass through the MLP layers with dropout
        x = torch.relu(self.fc1(inputs))  # Activation function after first layer
        x = self.dropout(x)  # Dropout after first layer
        x = torch.relu(self.fc2(x))  # Activation function after second layer
        x = self.dropout(x)  # Dropout after second layer
        x = torch.relu(self.fc3(x))  # Activation function after third layer
        x = self.dropout(x)  # Dropout after third layer
        x = torch.relu(self.fc4(x))  # Activation function after fourth layer
        x = self.dropout(x)  # Dropout after fourth layer
        x = self.fc5(x)  # Output layer

        # Reshape the output to match the expected output shape
        return x.view(-1, 1, 16, 32)  # Shape: (batch_size, 1, 16, 32)

class WeatherData(Dataset):
    def __init__(self, dataset: xr.Dataset, window_size: int = 24, steps: int = 3, auto = False, use_forcings = False, intervals = 1):
        self.dataset = dataset
        self.window_size = window_size
        self.steps = steps
        self.calculate_wind_speed()
        self.dataset = self.dataset.sortby('latitude')

        self.min_value = self.dataset.wspd.min().item()
        self.max_value = self.dataset.wspd.max().item()

        self.mean_value = self.dataset.wspd.mean().item()
        self.std_value = self.dataset.wspd.std().item()

        self.use_forcings = use_forcings

        if auto:
            if intervals > 1:
                self.time_intervals(intervals)
            self.window_dataset()
            self.split_data()    
            self.normalize_data()    

    def __len__(self):
        return len(self.X_train)
    
    def __getitem__(self, idx):
        return self.X_train_t[idx], self.F_train_t[idx], self.y_train_t[idx]
    
    def time_intervals(self, intervals = 3):
        self.dataset = self.dataset.sel(time=slice(None, None, intervals))

    def subset_data(self, coarsen = 1):
        if coarsen > 1:
            lat_slice = slice(1, 33, coarsen)
            lon_slice = slice(3, 67, coarsen)
        else:
            lat_slice = slice(1, 33)  
            lon_slice = slice(3, 67)

        self.dataset = self.dataset.isel(latitude=lat_slice, longitude=lon_slice)

    def calculate_wind_speed(self):
        self.dataset['wspd'] = np.sqrt(self.dataset.u**2 + self.dataset.v**2).astype(np.float32)
        self.dataset.attrs['wspd_units'] = 'm/s'
        # self.dataset['wdir'] = np.arctan2(self.dataset.v, self.dataset.u) * 180 / np.pi
        # self.dataset.attrs['wdir_units'] = 'degrees'

    def window_dataset(self, variable: str = 'wspd'):
        time_dim = self.dataset.sizes['time']
        total_windows = time_dim - self.window_size - self.steps

        # Preallocate arrays for better performance
        features = np.empty((total_windows, self.window_size, self.dataset.sizes['latitude'], self.dataset.sizes['longitude']), dtype=np.float32)
        targets = np.empty((total_windows,  self.steps, self.dataset.sizes['latitude'], self.dataset.sizes['longitude']), dtype=np.float32)
        forcings = np.empty((total_windows, 2), dtype=np.int32)
        time_values = np.empty((total_windows, self.window_size), dtype='datetime64[ns]')

        # Slice the dataset for all the time values at once
        dataset_time = self.dataset.time.values
        dataset_hour = self.dataset.time.dt.hour.values
        dataset_month = self.dataset.time.dt.month.values

        # Vectorized slicing
        for i in range(total_windows):
            print(f'{i}/{total_windows}', end='\r')
            
            # Slice features, targets, time values, and forcings in batches
            features[i] = self.dataset[variable].isel(time=slice(i, i + self.window_size)).values
            targets[i] = self.dataset[variable].isel(time=slice(i + self.window_size, i + self.window_size + self.steps)).values
            time_values[i] = dataset_time[i:i + self.window_size]

            # Hour and month forcings
            forcings[i] = [dataset_hour[i + self.window_size], dataset_month[i + self.window_size]]

        # Save arrays as attributes
        self.features = features
        self.targets = targets
        self.forcings = forcings
        self.time_values = time_values

        print('Windowed...')

    def split_data(self, test_size=0.2, random_state=42):
        """
        Splits the data into training, validation, and test sets.
        """

        print('Splitting...')
        self.X_train, self.X_test, self.y_train, self.y_test, self.F_train, self.F_test, self.T_train, self.T_test = train_test_split(
            self.features, self.targets, self.forcings, self.time_values,
            test_size= test_size)
     
        print('Shuffling...')
        
        self.X_train, self.y_train, self.F_train, self.T_train = shuffle(self.X_train, self.y_train, self.F_train, self.T_train, random_state=random_state)

    def normalize_data(self):
        # Normalize the data with standard deviation
        self.X_train_t = (self.X_train - self.mean_value) / self.std_value
        self.y_train_t = (self.y_train - self.mean_value) / self.std_value

        self.X_test_t = (self.X_test - self.mean_value) / self.std_value
        self.y_test_t = (self.y_test - self.mean_value) / self.std_value

        self.F_train_t = self.F_train / 24
        self.F_test_t = self.F_test / 24

        # To tensors
        self.X_train_t = torch.tensor(self.X_train_t).float()
        self.y_train_t = torch.tensor(self.y_train_t).float()
        
        self.X_test_t = torch.tensor(self.X_test_t).float()
        self.y_test_t = torch.tensor(self.y_test_t).float()

        self.F_train_t = torch.tensor(self.F_train_t).float()
        self.F_test_t = torch.tensor(self.F_test_t).float()

    def plot_from_ds(self, seed = 0, frame_rate=16, levels =10):
        bounds = [self.dataset.longitude.min().item(), self.dataset.longitude.max().item(), self.dataset.latitude.min().item(), self.dataset.latitude.max().item()]
        features = self.features[seed]
        targets = self.targets[seed]
        time_values = self.time_values

        features = features * (self.max_value - self.min_value) + self.min_value
        targets = targets * (self.max_value - self.min_value) + self.min_value

        fig, axs = plt.subplots(1, 2, figsize=(21, 7), subplot_kw={'projection': ccrs.PlateCarree()})

        vmin = min(features.min().item(), targets.min().item())
        vmax = max(features.max().item(), targets.max().item())

        fig.subplots_adjust(left=0.05, right=0.95, bottom=0.1, top=0.9, wspace=0.2)

        for ax in axs:
            ax.set_extent(bounds, crs=ccrs.PlateCarree())
            ax.coastlines()


        feat = axs[0].contourf(self.dataset.longitude, self.dataset.latitude, features[0], levels=levels, vmin=vmin, vmax = vmax, transform=ccrs.PlateCarree())
        tar = axs[1].contourf(self.dataset.longitude, self.dataset.latitude, targets[0], levels=levels, vmin=vmin, vmax = vmax, transform=ccrs.PlateCarree())
        axs[1].set_title('Target')

        fig.colorbar(feat, ax=axs[0], orientation='vertical', label='Wind Speed (m/s)')
        fig.colorbar(tar, ax=axs[1], orientation='vertical', label='Wind Speed (m/s)')

        def animate(i):
            axs[0].clear()
            axs[0].coastlines()

            pcm = axs[0].contourf(self.dataset.longitude, self.dataset.latitude, features[i], levels=levels, vmin=vmin, vmax = vmax)
            

            start_time = time_values[i][0]
            end_time = time_values[i][-1]

            start_time = pd.to_datetime(start_time)
            end_time = pd.to_datetime(end_time)

            axs[0].set_title(f'Window {i} - {start_time.strftime("%Y-%m-%d %H:%M:%S")} to {end_time.strftime("%Y-%m-%d %H:%M:%S")}')
            if self.steps > 1:
                ptm = axs[1].contourf(self.dataset.longitude, self.dataset.latitude, targets[i % self.steps], levels=levels, vmin=vmin, vmax = vmax)
                axs[1].set_title(f'Target - {end_time.strftime("%Y-%m-%d %H:%M:%S")}')
            return pcm

            
        frames = features.shape[0]

        interval = 1000 / frame_rate

        ani = FuncAnimation(fig, animate, frames=frames, interval=interval)

        plt.close(fig)

        return HTML(ani.to_jshtml())

    def plot_from_data(self, seed = 0, frame_rate=16, levels =10):
        bounds = [self.dataset.longitude.min().item(), self.dataset.longitude.max().item(), self.dataset.latitude.min().item(), self.dataset.latitude.max().item()]
        features = self.X_test[seed:seed+1]
        targets = self.y_test[seed:seed+1]
        time_values = self.time_values

        features = features * (self.max_value - self.min_value) + self.min_value
        targets = targets * (self.max_value - self.min_value) + self.min_value

        fig, axs = plt.subplots(1, 2, figsize=(21, 7), subplot_kw={'projection': ccrs.PlateCarree()})

        vmin = min(features.min().item(), targets.min().item())
        vmax = max(features.max().item(), targets.max().item())

        fig.subplots_adjust(left=0.05, right=0.95, bottom=0.1, top=0.9, wspace=0.2)

        for ax in axs:
            ax.set_extent(bounds, crs=ccrs.PlateCarree())
            ax.coastlines()


        feat = axs[0].contourf(self.dataset.longitude, self.dataset.latitude, features[0,0], levels=levels, vmin=vmin, vmax = vmax, transform=ccrs.PlateCarree())
        tar = axs[1].contourf(self.dataset.longitude, self.dataset.latitude, targets[0,0], levels=levels, vmin=vmin, vmax = vmax, transform=ccrs.PlateCarree())
        axs[1].set_title('Target')

        fig.colorbar(feat, ax=axs[0], orientation='vertical', label='Wind Speed (m/s)')
        fig.colorbar(tar, ax=axs[1], orientation='vertical', label='Wind Speed (m/s)')

        def animate(i):
            axs[0].clear()
            axs[0].coastlines()

            pcm = axs[0].contourf(self.dataset.longitude, self.dataset.latitude, features[0,i], levels=levels, vmin=vmin, vmax = vmax)
            

            start_time = time_values[i][0]
            end_time = time_values[i][-1]

            start_time = pd.to_datetime(start_time)
            end_time = pd.to_datetime(end_time)

            axs[0].set_title(f'Window {i} - {start_time.strftime("%Y-%m-%d %H:%M:%S")} to {end_time.strftime("%Y-%m-%d %H:%M:%S")}')
            if self.steps > 1:
                ptm = axs[1].contourf(self.dataset.longitude, self.dataset.latitude, targets[0,i % self.steps], levels=levels, vmin=vmin, vmax = vmax)
                axs[1].set_title(f'Target - {end_time.strftime("%Y-%m-%d %H:%M:%S")}')
            return pcm

            
        frames = features.shape[1]

        interval = 1000 / frame_rate

        ani = FuncAnimation(fig, animate, frames=frames, interval=interval)

        plt.close(fig)

        return HTML(ani.to_jshtml())

class TorchWeatherModel(WeatherData):
    def __init__(self, ds: xr.Dataset, window_size: int = 24, steps: int = 3, use_forcings = False, intervals = 1):
        super().__init__(dataset=ds, window_size=window_size, steps=steps, auto=True, use_forcings=use_forcings, intervals=intervals)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        print('Class setup done...')

    def assign_model(self, model):
        self.model = model

    def train_single(self, epochs=10, save_path=None, patience=5, lr_=0.0001, batch_size_=128):
        if save_path is None:
            save_path = f'{datetime.now().month}_{datetime.now().day}_{datetime.now().hour}_{datetime.now().minute}.pth'

        criterion = nn.MSELoss()
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=lr_)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

        print(f'Training on {self.device}')

        self.model.apply(self.init_weights)

        self.model.to(self.device)
        self.model.train()

        best_loss = float('inf')
        patience_counter = 0

        for epoch in range(epochs):
            epoch_loss = 0
            for X_batch, F_batch, y_batch in DataLoader(self, batch_size=batch_size_, shuffle=True):
                X_batch = X_batch.to(self.device)
                F_batch = F_batch.to(self.device)
                y_batch = y_batch.to(self.device)
                
                optimizer.zero_grad()

                if self.use_forcings:
                    outputs = self.model(X_batch, F_batch)
                else:
                    outputs = self.model(X_batch)

                loss = criterion(outputs, y_batch[:,0].reshape(-1, 1, self.dataset.latitude.size, self.dataset.longitude.size))

                loss.backward()

                torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)

                optimizer.step()
                
                epoch_loss += loss.item() * X_batch.size(0)

            avg_loss = epoch_loss / len(self.X_train)  # Assuming self.X_train is used for training

            scheduler.step(avg_loss)

            print(f'Epoch {epoch+1}/{epochs}, Loss: {avg_loss}, Best Loss: {best_loss}, LR: {optimizer.param_groups[0]["lr"]}')

            # Checkpointing
            if avg_loss < best_loss:
                best_loss = avg_loss
                patience_counter = 0
                torch.save(self.model.state_dict(), save_path)
                print(f'Saved best model to {save_path}')
            else:
                patience_counter += 1

            # Early stopping
            if patience_counter >= patience:
                print('Early stopping triggered')
                break

    def train_multi(self, epochs=10, save_path=None, patience=5, lr_=0.0001, batch_size_=128, train_steps=3, load_weights = None):
        if save_path is None:
            save_path = f'{datetime.now().month}_{datetime.now().day}_{datetime.now().hour}_{datetime.now().minute}.pth'

        criterion = nn.MSELoss()
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=lr_)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, verbose=True)

        print(f'Training on {self.device}')

        if load_weights is not None:
            self.load_model(load_weights)
        else:
            self.model.apply(self.init_weights)

        self.model.to(self.device)
        self.model.train()

        best_loss = float('inf')
        patience_counter = 0

        for epoch in range(epochs):
            epoch_loss = 0
            for X_batch, F_batch, y_batch in DataLoader(self, batch_size=batch_size_, shuffle=True):
                X_batch = X_batch.to(self.device)
                F_batch = F_batch.to(self.device)
                y_batch = y_batch.to(self.device)
                
                optimizer.zero_grad()

                cumulative_loss = 0.0
                current_input = X_batch.clone()  # Initialize predictions with the first input state
                current_F = F_batch.clone()

                

                # Autoregressive steps
                for step in range(train_steps):  # self.prediction_steps is how many steps you autoregress
                    # print('Step' , step)
                    if self.use_forcings:
                        outputs = self.model(current_input, current_F)
                    else:
                        outputs = self.model(current_input)
                    
                    # Calculate loss at each autoregressive step
                    loss = criterion(outputs, y_batch[:, step].reshape(-1, 1, self.dataset.latitude.size, self.dataset.longitude.size))
                    cumulative_loss += loss  # Accumulate the loss

                    # Use the predicted outputs as the next inputs
                    
                    current_input = torch.cat((current_input[:, 1:], outputs), dim=1).to(self.device)

                    hour = current_F[:, 0]
                    month = current_F[:, 1]
                    
                    hour = (hour + 1) % 24

                    current_F = torch.stack((hour, month), dim=1).float().to(self.device)

                # Backpropagate the cumulative loss
                cumulative_loss.backward()

                torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)

                optimizer.step()

                epoch_loss += cumulative_loss.item() * X_batch.size(0)

            avg_loss = epoch_loss / len(self.X_train)

            scheduler.step(avg_loss)

            print(f'Epoch {epoch+1}/{epochs}, Loss: {avg_loss}, Best Loss: {best_loss}, LR: {optimizer.param_groups[0]["lr"]}')

            # Checkpointing
            if avg_loss < best_loss:
                best_loss = avg_loss
                patience_counter = 0
                torch.save(self.model.state_dict(), save_path)
                print(f'Saved best model to {save_path}')
            else:
                patience_counter += 1

            # Early stopping
            if patience_counter >= patience:
                print('Early stopping triggered')
                break

    def init_weights(self, m):
        if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)  # Xavier initialization for Conv and Linear layers
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)  # Initialize bias to 0

    def predict(self, X, F):
        self.model.eval()
        with torch.no_grad():
            X = torch.tensor(X).float()
            F = torch.tensor(F).float()
            if self.use_forcings:
                return self.model(X, F).numpy()
            else:
                return self.model(X).numpy() # , F

    def autoregressive_predict(self, X, F, rollout_steps, unnormalize=True, verbose=False):
        self.model.eval()
        with torch.no_grad():
            
            # X = torch.tensor(X).float()
            F = torch.tensor(F).float()
            
            predictions = []

            current_input = X.to(self.device)
            current_F = F.to(self.device)
            
            for step in range(rollout_steps):
                
                if self.use_forcings:
                    next_pred = self.model(current_input, current_F).cpu().numpy()
                else:
                    try:
                        next_pred = self.model(current_input).cpu().numpy()
                    except:
                        next_pred = self.model(current_input).numpy()
                
                predictions.append(next_pred)
                
                next_pred_tensor = torch.tensor(next_pred).float().to(self.device) 

                if verbose:
                    print(current_input.shape, next_pred_tensor.shape)

                current_input = torch.cat((current_input[:, 1:], next_pred_tensor), dim=1).to(self.device)

                hour = current_F[0, 0].item()  # Extract the hour
                month = current_F[0, 1].item()  # Extract the month
                
                hour += 1
                if hour == 24:
                    hour = 0
                
                current_F = torch.tensor([[hour, month]]).float().to(self.device)

            predictions = np.array(predictions).reshape(rollout_steps, self.dataset.sizes['latitude'], self.dataset.sizes['longitude'])

            # Unnromalize the predictions
            if unnormalize:
                predictions = predictions * self.std_value + self.mean_value
            
            return predictions
        
    def save_model(self, file_path):
        torch.save(self.model.state_dict(), file_path)

    def load_model(self, file_path):
        self.model.load_state_dict(torch.load(file_path, map_location=self.device, weights_only=True))
        self.model.to(self.device)
        self.model.eval()

    def plot_pred_target(self, seed = 0, frame_rate=16, levels = 10):
        bounds = [self.dataset.longitude.min().item(), self.dataset.longitude.max().item(), self.dataset.latitude.min().item(), self.dataset.latitude.max().item()]
        targets = self.y_test[seed:seed+1]
        time_values = self.time_values

        predictions = self.autoregressive_predict(self.X_test_t[seed:seed+1], self.F_test_t[seed:seed+1], self.steps)

        fig, axs = plt.subplots(1, 3, figsize=(21, 7), subplot_kw={'projection': ccrs.PlateCarree()})

        vmin = min(predictions.min().item(), targets.min().item())
        vmax = max(predictions.max().item(), targets.max().item())

        fig.subplots_adjust(left=0.05, right=0.95, bottom=0.1, top=0.9, wspace=0.2)

        for ax in axs:
            ax.set_extent(bounds, crs=ccrs.PlateCarree())
            ax.coastlines()


        pred = axs[0].contourf(self.dataset.longitude, self.dataset.latitude, predictions[0], levels=levels, vmin=vmin, vmax = vmax, transform=ccrs.PlateCarree())
        tar = axs[1].contourf(self.dataset.longitude, self.dataset.latitude, targets[0,0], levels=levels, vmin=vmin, vmax = vmax, transform=ccrs.PlateCarree())
        error = (predictions[0] - targets[0,0].squeeze()) / vmax * 100
        err = axs[2].contourf(self.dataset.longitude, self.dataset.latitude, error.squeeze(), levels=levels, transform=ccrs.PlateCarree(), cmap='coolwarm')
        axs[1].set_title('Target')
        axs[0].set_title('Prediction')
        axs[2].set_title('Absolute Error')

        fig.colorbar(pred, ax=axs[0], orientation='vertical', label='Wind Speed (m/s)')
        fig.colorbar(tar, ax=axs[1], orientation='vertical', label='Wind Speed (m/s)')
        fig.colorbar(err, ax=axs[2], orientation='vertical', label='Percentage Error (%)')

        def animate(i):
            axs[0].clear()
            axs[0].coastlines()

            pcm = axs[0].contourf(self.dataset.longitude, self.dataset.latitude, predictions[i], levels=levels, vmin=vmin, vmax = vmax)
            ptm = axs[1].contourf(self.dataset.longitude, self.dataset.latitude, targets[0,i % self.steps], levels=levels, vmin=vmin, vmax = vmax)
            
            err = axs[2].contourf(self.dataset.longitude, self.dataset.latitude, predictions[i] - targets[0,i % self.steps].squeeze(), levels=levels, transform=ccrs.PlateCarree(), cmap='coolwarm')
            

            start_time = time_values[i][0]
            end_time = time_values[i][-1]

            start_time = pd.to_datetime(start_time)
            end_time = pd.to_datetime(end_time)

            axs[0].set_title(f'Prediction {i} - {start_time.strftime("%Y-%m-%d %H:%M:%S")} to {end_time.strftime("%Y-%m-%d %H:%M:%S")}')  
            axs[1].set_title(f'Target - {end_time.strftime("%Y-%m-%d %H:%M:%S")}')
            axs[2].set_title(f'Error - {end_time.strftime("%Y-%m-%d %H:%M:%S")}')

            return pcm

            
        frames = predictions.shape[0]

        interval = 1000 / frame_rate

        ani = FuncAnimation(fig, animate, frames=frames, interval=interval)

        plt.close(fig)

        return HTML(ani.to_jshtml())

    def prediction_plots(self, seed = 0):
        targets = self.y_test[seed:seed+1]

        predictions = self.autoregressive_predict(self.X_test_t[seed:seed+1], self.F_test_t[seed:seed+1], self.steps)

        fig, axs = plt.subplots(3, self.steps, figsize=(21, 7), subplot_kw={'projection': ccrs.PlateCarree()})

        # Set titles for each row
        titles_top = 'True States'
        titles_middle = 'Predictions'
        titles_bottom = 'Errors'

        # Add coastlines and titles
        for i, ax in enumerate(axs.flatten()):
            ax.coastlines()

        axs[0, self.steps // 2].set_title(f'{titles_top} @ {self.T_test[seed,0]}', fontsize=12)
        axs[1, self.steps // 2].set_title(titles_middle, fontsize=12)
        axs[2, self.steps // 2].set_title(titles_bottom, fontsize=12)

        for i in range(self.steps):
            feat = axs[0, i].contourf(ds.longitude, ds.latitude, targets[0, i], levels=10, transform=ccrs.PlateCarree())
            tar = axs[1, i].contourf(ds.longitude, ds.latitude, predictions[i], levels=10, transform=ccrs.PlateCarree())
            err = axs[2, i].contourf(ds.longitude, ds.latitude, predictions[i] - targets[0, i], levels=10, transform=ccrs.PlateCarree(), cmap='coolwarm')

        cbar_feat = fig.colorbar(feat, ax=axs[0, :], orientation='vertical', fraction=0.046, pad=0.04)
        cbar_tar = fig.colorbar(tar, ax=axs[1, :], orientation='vertical', fraction=0.046, pad=0.04)
        cbar_err = fig.colorbar(err, ax=axs[2, :], orientation='vertical', fraction=0.046, pad=0.04)

        plt.show()

# %% [markdown]
# ### Usage

# %%
model_class = TorchWeatherModel(ds, window_size=15, steps=13, use_forcings=True, intervals=3)
# Out:
# Windowed...
# Splitting...
# Shuffling...
# Class setup done...

# %%
# Define model input and output sizes
input_size = 10 * 16 * 32  # Flattened input size from X
forcing_size = 2  # Size of the forcing input
output_size = 1 * 16 * 32  # Flattened output size

# Instantiate the model
model = LargerMLP(input_size=input_size, forcing_size=forcing_size, output_size=output_size)

# Example of model forward pass
X_example = torch.randn(1, 10, 16, 32)  # Example input
F_example = torch.randn(1, 2)  # Example forcing input
y_output = model(X_example, F_example)  # Model output

print("Model output shape:", y_output.shape, model_class.y_train_t[0:1].shape)  # Should be [1, 1, 16, 32]
# Out:
# Model output shape: torch.Size([1, 1, 16, 32]) torch.Size([1, 13, 16, 32])

# %%
input_size = model_class.window_size * model_class.dataset.latitude.size * model_class.dataset.longitude.size
forcing_size = 2  # Size of the forcing input
output_size = 1 * model_class.dataset.latitude.size * model_class.dataset.longitude.size 

model = SimpleMLP(input_size=input_size, forcing_size=forcing_size, output_size=output_size)

model_class.assign_model(model)

# %%
model_class.train_single(epochs=500, save_path='MLP_15to1_s32.pth', patience=10, lr_=0.0001, batch_size_=128)
# Out:
# c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Training on cpu
# Epoch 1/500, Loss: 1.0115300396846272, Best Loss: inf, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 2/500, Loss: 0.9663650219542507, Best Loss: 1.0115300396846272, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 3/500, Loss: 0.9384250404563653, Best Loss: 0.9663650219542507, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 4/500, Loss: 0.8977184819031009, Best Loss: 0.9384250404563653, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 5/500, Loss: 0.8412972553127831, Best Loss: 0.8977184819031009, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 6/500, Loss: 0.7745080724764427, Best Loss: 0.8412972553127831, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 7/500, Loss: 0.703404578511147, Best Loss: 0.7745080724764427, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 8/500, Loss: 0.640272548355378, Best Loss: 0.703404578511147, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 9/500, Loss: 0.587238930465337, Best Loss: 0.640272548355378, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 10/500, Loss: 0.5432627493305429, Best Loss: 0.587238930465337, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 11/500, Loss: 0.5084091911468472, Best Loss: 0.5432627493305429, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 12/500, Loss: 0.47796611930455063, Best Loss: 0.5084091911468472, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 13/500, Loss: 0.45295481365117685, Best Loss: 0.47796611930455063, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 14/500, Loss: 0.4310284883776012, Best Loss: 0.45295481365117685, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 15/500, Loss: 0.41352717780056736, Best Loss: 0.4310284883776012, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 16/500, Loss: 0.3978987828869867, Best Loss: 0.41352717780056736, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 17/500, Loss: 0.38325300004850255, Best Loss: 0.3978987828869867, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 18/500, Loss: 0.3712767793459136, Best Loss: 0.38325300004850255, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 19/500, Loss: 0.35904857042131616, Best Loss: 0.3712767793459136, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 20/500, Loss: 0.34914173347528393, Best Loss: 0.35904857042131616, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 21/500, Loss: 0.3397336505060324, Best Loss: 0.34914173347528393, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 22/500, Loss: 0.3317080249504975, Best Loss: 0.3397336505060324, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 23/500, Loss: 0.32345629405831033, Best Loss: 0.3317080249504975, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 24/500, Loss: 0.31675088617562525, Best Loss: 0.32345629405831033, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 25/500, Loss: 0.30983559345972267, Best Loss: 0.31675088617562525, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 26/500, Loss: 0.3049761925200286, Best Loss: 0.30983559345972267, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 27/500, Loss: 0.29883231979605956, Best Loss: 0.3049761925200286, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 28/500, Loss: 0.2938426646560598, Best Loss: 0.29883231979605956, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 29/500, Loss: 0.2896947835334905, Best Loss: 0.2938426646560598, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 30/500, Loss: 0.2846857485217652, Best Loss: 0.2896947835334905, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 31/500, Loss: 0.28086366392655954, Best Loss: 0.2846857485217652, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 32/500, Loss: 0.2770308789576074, Best Loss: 0.28086366392655954, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 33/500, Loss: 0.272919358111438, Best Loss: 0.2770308789576074, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 34/500, Loss: 0.2689279106933216, Best Loss: 0.272919358111438, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 35/500, Loss: 0.26565877975347596, Best Loss: 0.2689279106933216, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 36/500, Loss: 0.26246593676755503, Best Loss: 0.26565877975347596, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 37/500, Loss: 0.25992431651705844, Best Loss: 0.26246593676755503, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 38/500, Loss: 0.2575075283124753, Best Loss: 0.25992431651705844, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 39/500, Loss: 0.2538380227818718, Best Loss: 0.2575075283124753, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 40/500, Loss: 0.251551647233695, Best Loss: 0.2538380227818718, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 41/500, Loss: 0.2492180498412714, Best Loss: 0.251551647233695, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 42/500, Loss: 0.2455976652186823, Best Loss: 0.2492180498412714, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 43/500, Loss: 0.24295070032330235, Best Loss: 0.2455976652186823, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 44/500, Loss: 0.24008040072157225, Best Loss: 0.24295070032330235, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 45/500, Loss: 0.23865716689549327, Best Loss: 0.24008040072157225, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 46/500, Loss: 0.23552365762121585, Best Loss: 0.23865716689549327, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 47/500, Loss: 0.2324343008161158, Best Loss: 0.23552365762121585, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 48/500, Loss: 0.22986155211075116, Best Loss: 0.2324343008161158, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 49/500, Loss: 0.22793602499542326, Best Loss: 0.22986155211075116, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 50/500, Loss: 0.22540570139704563, Best Loss: 0.22793602499542326, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 51/500, Loss: 0.22296370499535037, Best Loss: 0.22540570139704563, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 52/500, Loss: 0.22155816410456805, Best Loss: 0.22296370499535037, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 53/500, Loss: 0.21888543291108412, Best Loss: 0.22155816410456805, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 54/500, Loss: 0.21673190020350117, Best Loss: 0.21888543291108412, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 55/500, Loss: 0.2148883607523605, Best Loss: 0.21673190020350117, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 56/500, Loss: 0.21194386625258993, Best Loss: 0.2148883607523605, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 57/500, Loss: 0.2100865697762794, Best Loss: 0.21194386625258993, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 58/500, Loss: 0.20925896041098477, Best Loss: 0.2100865697762794, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 59/500, Loss: 0.20683665588414366, Best Loss: 0.20925896041098477, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 60/500, Loss: 0.20501623762359983, Best Loss: 0.20683665588414366, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 61/500, Loss: 0.2032017008185232, Best Loss: 0.20501623762359983, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 62/500, Loss: 0.2000699983341994, Best Loss: 0.2032017008185232, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 63/500, Loss: 0.1979452615698024, Best Loss: 0.2000699983341994, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 64/500, Loss: 0.19654034053640246, Best Loss: 0.1979452615698024, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 65/500, Loss: 0.19435778041191035, Best Loss: 0.19654034053640246, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 66/500, Loss: 0.19248990266806523, Best Loss: 0.19435778041191035, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 67/500, Loss: 0.1907076745052849, Best Loss: 0.19248990266806523, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 68/500, Loss: 0.18908879943626863, Best Loss: 0.1907076745052849, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 69/500, Loss: 0.18815168002648525, Best Loss: 0.18908879943626863, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 70/500, Loss: 0.18589515305034432, Best Loss: 0.18815168002648525, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 71/500, Loss: 0.18499129291638325, Best Loss: 0.18589515305034432, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 72/500, Loss: 0.1831991965642905, Best Loss: 0.18499129291638325, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 73/500, Loss: 0.18183511214703643, Best Loss: 0.1831991965642905, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 74/500, Loss: 0.1800908267214553, Best Loss: 0.18183511214703643, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 75/500, Loss: 0.17883359826698583, Best Loss: 0.1800908267214553, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 76/500, Loss: 0.17926793191477275, Best Loss: 0.17883359826698583, LR: 0.0001
# Epoch 77/500, Loss: 0.17655060851001864, Best Loss: 0.17883359826698583, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 78/500, Loss: 0.17508360986399332, Best Loss: 0.17655060851001864, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 79/500, Loss: 0.17450946938267425, Best Loss: 0.17508360986399332, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 80/500, Loss: 0.17290820757960326, Best Loss: 0.17450946938267425, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 81/500, Loss: 0.1718334998473222, Best Loss: 0.17290820757960326, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 82/500, Loss: 0.1709555417582734, Best Loss: 0.1718334998473222, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 83/500, Loss: 0.17145066369136483, Best Loss: 0.1709555417582734, LR: 0.0001
# Epoch 84/500, Loss: 0.1699527948063996, Best Loss: 0.1709555417582734, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 85/500, Loss: 0.1678175773267049, Best Loss: 0.1699527948063996, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 86/500, Loss: 0.16625613547536236, Best Loss: 0.1678175773267049, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 87/500, Loss: 0.16659340542655357, Best Loss: 0.16625613547536236, LR: 0.0001
# Epoch 88/500, Loss: 0.1654959865787356, Best Loss: 0.16625613547536236, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 89/500, Loss: 0.16385274276401487, Best Loss: 0.1654959865787356, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 90/500, Loss: 0.16345772297285463, Best Loss: 0.16385274276401487, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 91/500, Loss: 0.1623916356364113, Best Loss: 0.16345772297285463, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 92/500, Loss: 0.1616603451286927, Best Loss: 0.1623916356364113, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 93/500, Loss: 0.160316621173629, Best Loss: 0.1616603451286927, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 94/500, Loss: 0.15939457148919103, Best Loss: 0.160316621173629, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 95/500, Loss: 0.15855376578954408, Best Loss: 0.15939457148919103, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 96/500, Loss: 0.1576399354000809, Best Loss: 0.15855376578954408, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 97/500, Loss: 0.15708186761852574, Best Loss: 0.1576399354000809, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 98/500, Loss: 0.15670702344557963, Best Loss: 0.15708186761852574, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 99/500, Loss: 0.15568963721413867, Best Loss: 0.15670702344557963, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 100/500, Loss: 0.15519313663050976, Best Loss: 0.15568963721413867, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 101/500, Loss: 0.15465055550402293, Best Loss: 0.15519313663050976, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 102/500, Loss: 0.15371995737838168, Best Loss: 0.15465055550402293, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 103/500, Loss: 0.1537296410458355, Best Loss: 0.15371995737838168, LR: 0.0001
# Epoch 104/500, Loss: 0.15240346937018764, Best Loss: 0.15371995737838168, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 105/500, Loss: 0.15252700104014574, Best Loss: 0.15240346937018764, LR: 0.0001
# Epoch 106/500, Loss: 0.15156046570094694, Best Loss: 0.15240346937018764, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 107/500, Loss: 0.1501910357739675, Best Loss: 0.15156046570094694, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 108/500, Loss: 0.14972164513767924, Best Loss: 0.1501910357739675, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 109/500, Loss: 0.1493146889494757, Best Loss: 0.14972164513767924, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 110/500, Loss: 0.14822034421185626, Best Loss: 0.1493146889494757, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 111/500, Loss: 0.1474502787696197, Best Loss: 0.14822034421185626, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 112/500, Loss: 0.1468377567141591, Best Loss: 0.1474502787696197, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 113/500, Loss: 0.14704356529060195, Best Loss: 0.1468377567141591, LR: 0.0001
# Epoch 114/500, Loss: 0.1465927791116148, Best Loss: 0.1468377567141591, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 115/500, Loss: 0.14545395260397304, Best Loss: 0.1465927791116148, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 116/500, Loss: 0.14505410575784236, Best Loss: 0.14545395260397304, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 117/500, Loss: 0.14408334400351822, Best Loss: 0.14505410575784236, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 118/500, Loss: 0.14360293379424713, Best Loss: 0.14408334400351822, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 119/500, Loss: 0.14366087877951397, Best Loss: 0.14360293379424713, LR: 0.0001
# Epoch 120/500, Loss: 0.14245436710039364, Best Loss: 0.14360293379424713, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 121/500, Loss: 0.14222530297809383, Best Loss: 0.14245436710039364, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 122/500, Loss: 0.14179507941587427, Best Loss: 0.14222530297809383, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 123/500, Loss: 0.1426469710447342, Best Loss: 0.14179507941587427, LR: 0.0001
# Epoch 124/500, Loss: 0.14058128755637903, Best Loss: 0.14179507941587427, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 125/500, Loss: 0.13980854028522632, Best Loss: 0.14058128755637903, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 126/500, Loss: 0.13904913203364783, Best Loss: 0.13980854028522632, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 127/500, Loss: 0.1397281550402462, Best Loss: 0.13904913203364783, LR: 0.0001
# Epoch 128/500, Loss: 0.13903293255805144, Best Loss: 0.13904913203364783, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 129/500, Loss: 0.1375122941833938, Best Loss: 0.13903293255805144, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 130/500, Loss: 0.13735688541856, Best Loss: 0.1375122941833938, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 131/500, Loss: 0.13640140701154585, Best Loss: 0.13735688541856, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 132/500, Loss: 0.13610161329715015, Best Loss: 0.13640140701154585, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 133/500, Loss: 0.1354961544919519, Best Loss: 0.13610161329715015, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 134/500, Loss: 0.13476528624178163, Best Loss: 0.1354961544919519, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 135/500, Loss: 0.13445599803639036, Best Loss: 0.13476528624178163, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 136/500, Loss: 0.13433007209835968, Best Loss: 0.13445599803639036, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 137/500, Loss: 0.13345825797131294, Best Loss: 0.13433007209835968, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 138/500, Loss: 0.13339332850642704, Best Loss: 0.13345825797131294, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 139/500, Loss: 0.13266217208661096, Best Loss: 0.13339332850642704, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 140/500, Loss: 0.13343322641062005, Best Loss: 0.13266217208661096, LR: 0.0001
# Epoch 141/500, Loss: 0.1319640990792803, Best Loss: 0.13266217208661096, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 142/500, Loss: 0.13163233469483968, Best Loss: 0.1319640990792803, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 143/500, Loss: 0.131658412422703, Best Loss: 0.13163233469483968, LR: 0.0001
# Epoch 144/500, Loss: 0.13054309530893138, Best Loss: 0.13163233469483968, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 145/500, Loss: 0.1302743957277711, Best Loss: 0.13054309530893138, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 146/500, Loss: 0.12938222694309356, Best Loss: 0.1302743957277711, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 147/500, Loss: 0.12908740884753672, Best Loss: 0.12938222694309356, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 148/500, Loss: 0.12868124928198177, Best Loss: 0.12908740884753672, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 149/500, Loss: 0.12817930931388893, Best Loss: 0.12868124928198177, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 150/500, Loss: 0.1276250491591176, Best Loss: 0.12817930931388893, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 151/500, Loss: 0.12716358731280555, Best Loss: 0.1276250491591176, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 152/500, Loss: 0.12640028778371798, Best Loss: 0.12716358731280555, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 153/500, Loss: 0.12618483106939504, Best Loss: 0.12640028778371798, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 154/500, Loss: 0.1261786022487266, Best Loss: 0.12618483106939504, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 155/500, Loss: 0.12565426922725798, Best Loss: 0.1261786022487266, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 156/500, Loss: 0.1252562890656315, Best Loss: 0.12565426922725798, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 157/500, Loss: 0.12459152764280379, Best Loss: 0.1252562890656315, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 158/500, Loss: 0.12431317572334964, Best Loss: 0.12459152764280379, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 159/500, Loss: 0.123586565333427, Best Loss: 0.12431317572334964, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 160/500, Loss: 0.12324354189121511, Best Loss: 0.123586565333427, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 161/500, Loss: 0.12344628989284193, Best Loss: 0.12324354189121511, LR: 0.0001
# Epoch 162/500, Loss: 0.12266337526241423, Best Loss: 0.12324354189121511, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 163/500, Loss: 0.12214377942187829, Best Loss: 0.12266337526241423, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 164/500, Loss: 0.12186146071732328, Best Loss: 0.12214377942187829, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 165/500, Loss: 0.12221009711063738, Best Loss: 0.12186146071732328, LR: 0.0001
# Epoch 166/500, Loss: 0.12171070189108542, Best Loss: 0.12186146071732328, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 167/500, Loss: 0.12080118420883736, Best Loss: 0.12171070189108542, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 168/500, Loss: 0.12013344345570023, Best Loss: 0.12080118420883736, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 169/500, Loss: 0.11955786590137062, Best Loss: 0.12013344345570023, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 170/500, Loss: 0.11960272339582959, Best Loss: 0.11955786590137062, LR: 0.0001
# Epoch 171/500, Loss: 0.12021221201810495, Best Loss: 0.11955786590137062, LR: 0.0001
# Epoch 172/500, Loss: 0.11918962675670602, Best Loss: 0.11955786590137062, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 173/500, Loss: 0.11841028808928958, Best Loss: 0.11918962675670602, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 174/500, Loss: 0.11790219064636041, Best Loss: 0.11841028808928958, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 175/500, Loss: 0.11760802584399509, Best Loss: 0.11790219064636041, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 176/500, Loss: 0.11722969876781873, Best Loss: 0.11760802584399509, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 177/500, Loss: 0.1167071616680551, Best Loss: 0.11722969876781873, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 178/500, Loss: 0.11630172372328168, Best Loss: 0.1167071616680551, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 179/500, Loss: 0.1164184575904462, Best Loss: 0.11630172372328168, LR: 0.0001
# Epoch 180/500, Loss: 0.11569604310144659, Best Loss: 0.11630172372328168, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 181/500, Loss: 0.1160313049037375, Best Loss: 0.11569604310144659, LR: 0.0001
# Epoch 182/500, Loss: 0.11537900328687709, Best Loss: 0.11569604310144659, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 183/500, Loss: 0.11493039172717724, Best Loss: 0.11537900328687709, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 184/500, Loss: 0.11492184340515747, Best Loss: 0.11493039172717724, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 185/500, Loss: 0.11468349546967159, Best Loss: 0.11492184340515747, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 186/500, Loss: 0.11372069364765533, Best Loss: 0.11468349546967159, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 187/500, Loss: 0.11324621984711777, Best Loss: 0.11372069364765533, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 188/500, Loss: 0.11428460813784981, Best Loss: 0.11324621984711777, LR: 0.0001
# Epoch 189/500, Loss: 0.11297668215778035, Best Loss: 0.11324621984711777, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 190/500, Loss: 0.11258214404520615, Best Loss: 0.11297668215778035, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 191/500, Loss: 0.1126272591306851, Best Loss: 0.11258214404520615, LR: 0.0001
# Epoch 192/500, Loss: 0.11243515164368709, Best Loss: 0.11258214404520615, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 193/500, Loss: 0.1118709632858692, Best Loss: 0.11243515164368709, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 194/500, Loss: 0.11246912122752004, Best Loss: 0.1118709632858692, LR: 0.0001
# Epoch 195/500, Loss: 0.11144015246779178, Best Loss: 0.1118709632858692, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 196/500, Loss: 0.11052789474997333, Best Loss: 0.11144015246779178, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 197/500, Loss: 0.11033298731030605, Best Loss: 0.11052789474997333, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 198/500, Loss: 0.11017270082784225, Best Loss: 0.11033298731030605, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 199/500, Loss: 0.10950688795511515, Best Loss: 0.11017270082784225, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 200/500, Loss: 0.10919476426103854, Best Loss: 0.10950688795511515, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 201/500, Loss: 0.10950603511972032, Best Loss: 0.10919476426103854, LR: 0.0001
# Epoch 202/500, Loss: 0.10944244276508334, Best Loss: 0.10919476426103854, LR: 0.0001
# Epoch 203/500, Loss: 0.10873353517369898, Best Loss: 0.10919476426103854, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 204/500, Loss: 0.10869295871262936, Best Loss: 0.10873353517369898, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 205/500, Loss: 0.10864073346045643, Best Loss: 0.10869295871262936, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 206/500, Loss: 0.10781695053683593, Best Loss: 0.10864073346045643, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 207/500, Loss: 0.1071821448996734, Best Loss: 0.10781695053683593, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 208/500, Loss: 0.10691227941055913, Best Loss: 0.1071821448996734, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 209/500, Loss: 0.10716507326162485, Best Loss: 0.10691227941055913, LR: 0.0001
# Epoch 210/500, Loss: 0.10674057932473136, Best Loss: 0.10691227941055913, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 211/500, Loss: 0.10659918396170398, Best Loss: 0.10674057932473136, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 212/500, Loss: 0.10605426527273072, Best Loss: 0.10659918396170398, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 213/500, Loss: 0.10530440051268047, Best Loss: 0.10605426527273072, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 214/500, Loss: 0.10530819780270981, Best Loss: 0.10530440051268047, LR: 0.0001
# Epoch 215/500, Loss: 0.10531265135263397, Best Loss: 0.10530440051268047, LR: 0.0001
# Epoch 216/500, Loss: 0.1053254769940269, Best Loss: 0.10530440051268047, LR: 0.0001
# Epoch 217/500, Loss: 0.10464675541865687, Best Loss: 0.10530440051268047, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 218/500, Loss: 0.10415271226714505, Best Loss: 0.10464675541865687, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 219/500, Loss: 0.10398369773069192, Best Loss: 0.10415271226714505, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 220/500, Loss: 0.1037245419406293, Best Loss: 0.10398369773069192, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 221/500, Loss: 0.10400083535775652, Best Loss: 0.1037245419406293, LR: 0.0001
# Epoch 222/500, Loss: 0.10357438266225774, Best Loss: 0.1037245419406293, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 223/500, Loss: 0.10383201237821084, Best Loss: 0.10357438266225774, LR: 0.0001
# Epoch 224/500, Loss: 0.10337336383956468, Best Loss: 0.10357438266225774, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 225/500, Loss: 0.10275121588200344, Best Loss: 0.10337336383956468, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 226/500, Loss: 0.10259917231539963, Best Loss: 0.10275121588200344, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 227/500, Loss: 0.10219229232734073, Best Loss: 0.10259917231539963, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 228/500, Loss: 0.10198724960487125, Best Loss: 0.10219229232734073, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 229/500, Loss: 0.10153859010440572, Best Loss: 0.10198724960487125, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 230/500, Loss: 0.10128299432608971, Best Loss: 0.10153859010440572, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 231/500, Loss: 0.10092489585647632, Best Loss: 0.10128299432608971, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 232/500, Loss: 0.10132464279782653, Best Loss: 0.10092489585647632, LR: 0.0001
# Epoch 233/500, Loss: 0.10071241418829842, Best Loss: 0.10092489585647632, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 234/500, Loss: 0.10083958935966958, Best Loss: 0.10071241418829842, LR: 0.0001
# Epoch 235/500, Loss: 0.10030020638121395, Best Loss: 0.10071241418829842, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 236/500, Loss: 0.09979879505645646, Best Loss: 0.10030020638121395, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 237/500, Loss: 0.10008220445450075, Best Loss: 0.09979879505645646, LR: 0.0001
# Epoch 238/500, Loss: 0.09957350989569332, Best Loss: 0.09979879505645646, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 239/500, Loss: 0.09900497693779454, Best Loss: 0.09957350989569332, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 240/500, Loss: 0.09920324246011356, Best Loss: 0.09900497693779454, LR: 0.0001
# Epoch 241/500, Loss: 0.09871834757147133, Best Loss: 0.09900497693779454, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 242/500, Loss: 0.09827144644345961, Best Loss: 0.09871834757147133, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 243/500, Loss: 0.09804871052799934, Best Loss: 0.09827144644345961, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 244/500, Loss: 0.09801370831882082, Best Loss: 0.09804871052799934, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 245/500, Loss: 0.09780338999903465, Best Loss: 0.09801370831882082, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 246/500, Loss: 0.09789362936645063, Best Loss: 0.09780338999903465, LR: 0.0001
# Epoch 247/500, Loss: 0.0976252108554638, Best Loss: 0.09780338999903465, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 248/500, Loss: 0.09717123671058345, Best Loss: 0.0976252108554638, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 249/500, Loss: 0.09684856632829898, Best Loss: 0.09717123671058345, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 250/500, Loss: 0.09669456964659062, Best Loss: 0.09684856632829898, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 251/500, Loss: 0.09688027507484191, Best Loss: 0.09669456964659062, LR: 0.0001
# Epoch 252/500, Loss: 0.09632301651717676, Best Loss: 0.09669456964659062, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 253/500, Loss: 0.09625747783123235, Best Loss: 0.09632301651717676, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 254/500, Loss: 0.0964046024974682, Best Loss: 0.09625747783123235, LR: 0.0001
# Epoch 255/500, Loss: 0.09598705563267433, Best Loss: 0.09625747783123235, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 256/500, Loss: 0.09615010530774437, Best Loss: 0.09598705563267433, LR: 0.0001
# Epoch 257/500, Loss: 0.09561201035203327, Best Loss: 0.09598705563267433, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 258/500, Loss: 0.09664963161628379, Best Loss: 0.09561201035203327, LR: 0.0001
# Epoch 259/500, Loss: 0.09579639672472835, Best Loss: 0.09561201035203327, LR: 0.0001
# Epoch 260/500, Loss: 0.09533450085713242, Best Loss: 0.09561201035203327, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 261/500, Loss: 0.09482415778730734, Best Loss: 0.09533450085713242, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 262/500, Loss: 0.0944420213030367, Best Loss: 0.09482415778730734, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 263/500, Loss: 0.09436628100382936, Best Loss: 0.0944420213030367, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 264/500, Loss: 0.09415457541685933, Best Loss: 0.09436628100382936, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 265/500, Loss: 0.09370014204499116, Best Loss: 0.09415457541685933, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 266/500, Loss: 0.0934986329045174, Best Loss: 0.09370014204499116, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 267/500, Loss: 0.0931822523229884, Best Loss: 0.0934986329045174, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 268/500, Loss: 0.09327036082757482, Best Loss: 0.0931822523229884, LR: 0.0001
# Epoch 269/500, Loss: 0.09284132911666255, Best Loss: 0.0931822523229884, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 270/500, Loss: 0.09300004450585798, Best Loss: 0.09284132911666255, LR: 0.0001
# Epoch 271/500, Loss: 0.0928584158169311, Best Loss: 0.09284132911666255, LR: 0.0001
# Epoch 272/500, Loss: 0.09274738476846417, Best Loss: 0.09284132911666255, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 273/500, Loss: 0.09261940636459079, Best Loss: 0.09274738476846417, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 274/500, Loss: 0.0925185900814493, Best Loss: 0.09261940636459079, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 275/500, Loss: 0.0922923470523983, Best Loss: 0.0925185900814493, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 276/500, Loss: 0.09225320384724543, Best Loss: 0.0922923470523983, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 277/500, Loss: 0.09252435242426225, Best Loss: 0.09225320384724543, LR: 0.0001
# Epoch 278/500, Loss: 0.09228643684149097, Best Loss: 0.09225320384724543, LR: 0.0001
# Epoch 279/500, Loss: 0.09350345188077785, Best Loss: 0.09225320384724543, LR: 0.0001
# Epoch 280/500, Loss: 0.09256052359506983, Best Loss: 0.09225320384724543, LR: 0.0001
# Epoch 281/500, Loss: 0.09275626329325826, Best Loss: 0.09225320384724543, LR: 0.0001
# Epoch 282/500, Loss: 0.0916727472771518, Best Loss: 0.09225320384724543, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 283/500, Loss: 0.09114984534696949, Best Loss: 0.0916727472771518, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 284/500, Loss: 0.09064837473968484, Best Loss: 0.09114984534696949, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 285/500, Loss: 0.09028218305193393, Best Loss: 0.09064837473968484, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 286/500, Loss: 0.09009181281935844, Best Loss: 0.09028218305193393, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 287/500, Loss: 0.09013567941880979, Best Loss: 0.09009181281935844, LR: 0.0001
# Epoch 288/500, Loss: 0.08979111566811065, Best Loss: 0.09009181281935844, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 289/500, Loss: 0.08982608959858314, Best Loss: 0.08979111566811065, LR: 0.0001
# Epoch 290/500, Loss: 0.090017642270189, Best Loss: 0.08979111566811065, LR: 0.0001
# Epoch 291/500, Loss: 0.08942356972056861, Best Loss: 0.08979111566811065, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 292/500, Loss: 0.08912019243474342, Best Loss: 0.08942356972056861, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 293/500, Loss: 0.08937787400197014, Best Loss: 0.08912019243474342, LR: 0.0001
# Epoch 294/500, Loss: 0.08920537961918298, Best Loss: 0.08912019243474342, LR: 0.0001
# Epoch 295/500, Loss: 0.08915184461421076, Best Loss: 0.08912019243474342, LR: 0.0001
# Epoch 296/500, Loss: 0.08927962717379113, Best Loss: 0.08912019243474342, LR: 0.0001
# Epoch 297/500, Loss: 0.08865615986432547, Best Loss: 0.08912019243474342, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 298/500, Loss: 0.08853978697183171, Best Loss: 0.08865615986432547, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 299/500, Loss: 0.08833073841716323, Best Loss: 0.08853978697183171, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 300/500, Loss: 0.08909317812090357, Best Loss: 0.08833073841716323, LR: 0.0001
# Epoch 301/500, Loss: 0.08848218233604427, Best Loss: 0.08833073841716323, LR: 0.0001
# Epoch 302/500, Loss: 0.08867302585926295, Best Loss: 0.08833073841716323, LR: 0.0001
# Epoch 303/500, Loss: 0.08806766003009513, Best Loss: 0.08833073841716323, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 304/500, Loss: 0.0875200557981896, Best Loss: 0.08806766003009513, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 305/500, Loss: 0.0872254649533939, Best Loss: 0.0875200557981896, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 306/500, Loss: 0.08826968699397332, Best Loss: 0.0872254649533939, LR: 0.0001
# Epoch 307/500, Loss: 0.08768029451705242, Best Loss: 0.0872254649533939, LR: 0.0001
# Epoch 308/500, Loss: 0.08769118896344498, Best Loss: 0.0872254649533939, LR: 0.0001
# Epoch 309/500, Loss: 0.08721107643917428, Best Loss: 0.0872254649533939, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 310/500, Loss: 0.08692817296228829, Best Loss: 0.08721107643917428, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 311/500, Loss: 0.08657017260970257, Best Loss: 0.08692817296228829, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 312/500, Loss: 0.0863274872960129, Best Loss: 0.08657017260970257, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 313/500, Loss: 0.08645380996054919, Best Loss: 0.0863274872960129, LR: 0.0001
# Epoch 314/500, Loss: 0.08633997298413111, Best Loss: 0.0863274872960129, LR: 0.0001
# Epoch 315/500, Loss: 0.08615362922183065, Best Loss: 0.0863274872960129, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 316/500, Loss: 0.08595013368505963, Best Loss: 0.08615362922183065, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 317/500, Loss: 0.08601129304020115, Best Loss: 0.08595013368505963, LR: 0.0001
# Epoch 318/500, Loss: 0.08670824375752499, Best Loss: 0.08595013368505963, LR: 0.0001
# Epoch 319/500, Loss: 0.085942983401837, Best Loss: 0.08595013368505963, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 320/500, Loss: 0.08563794541606334, Best Loss: 0.085942983401837, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 321/500, Loss: 0.08561488264793964, Best Loss: 0.08563794541606334, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 322/500, Loss: 0.08519354390147131, Best Loss: 0.08561488264793964, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 323/500, Loss: 0.08515767141100755, Best Loss: 0.08519354390147131, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 324/500, Loss: 0.08482878415861843, Best Loss: 0.08515767141100755, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 325/500, Loss: 0.08489949720675327, Best Loss: 0.08482878415861843, LR: 0.0001
# Epoch 326/500, Loss: 0.08463542479047309, Best Loss: 0.08482878415861843, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 327/500, Loss: 0.08444132908077091, Best Loss: 0.08463542479047309, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 328/500, Loss: 0.08493429909420384, Best Loss: 0.08444132908077091, LR: 0.0001
# Epoch 329/500, Loss: 0.08463498945172813, Best Loss: 0.08444132908077091, LR: 0.0001
# Epoch 330/500, Loss: 0.08428994150992548, Best Loss: 0.08444132908077091, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 331/500, Loss: 0.0846113167216754, Best Loss: 0.08428994150992548, LR: 0.0001
# Epoch 332/500, Loss: 0.08437599255906726, Best Loss: 0.08428994150992548, LR: 0.0001
# Epoch 333/500, Loss: 0.08398248806718207, Best Loss: 0.08428994150992548, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 334/500, Loss: 0.08384842806972058, Best Loss: 0.08398248806718207, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 335/500, Loss: 0.0840641350066229, Best Loss: 0.08384842806972058, LR: 0.0001
# Epoch 336/500, Loss: 0.08370520726935048, Best Loss: 0.08384842806972058, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 337/500, Loss: 0.08373468663661035, Best Loss: 0.08370520726935048, LR: 0.0001
# Epoch 338/500, Loss: 0.0835627498523116, Best Loss: 0.08370520726935048, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 339/500, Loss: 0.08326322941928523, Best Loss: 0.0835627498523116, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 340/500, Loss: 0.08331248733358779, Best Loss: 0.08326322941928523, LR: 0.0001
# Epoch 341/500, Loss: 0.0831461830400462, Best Loss: 0.08326322941928523, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 342/500, Loss: 0.08301427164121052, Best Loss: 0.0831461830400462, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 343/500, Loss: 0.08394802009974317, Best Loss: 0.08301427164121052, LR: 0.0001
# Epoch 344/500, Loss: 0.0837501988066155, Best Loss: 0.08301427164121052, LR: 0.0001
# Epoch 345/500, Loss: 0.08282426608121607, Best Loss: 0.08301427164121052, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 346/500, Loss: 0.08254478474329212, Best Loss: 0.08282426608121607, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 347/500, Loss: 0.0823608103042756, Best Loss: 0.08254478474329212, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 348/500, Loss: 0.08245490785644675, Best Loss: 0.0823608103042756, LR: 0.0001
# Epoch 349/500, Loss: 0.0822976926640417, Best Loss: 0.0823608103042756, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 350/500, Loss: 0.08346094807929617, Best Loss: 0.0822976926640417, LR: 0.0001
# Epoch 351/500, Loss: 0.08300073800783264, Best Loss: 0.0822976926640417, LR: 0.0001
# Epoch 352/500, Loss: 0.08270183388567362, Best Loss: 0.0822976926640417, LR: 0.0001
# Epoch 353/500, Loss: 0.08270259367739335, Best Loss: 0.0822976926640417, LR: 0.0001
# Epoch 354/500, Loss: 0.08209096933475471, Best Loss: 0.0822976926640417, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 355/500, Loss: 0.08187246093928324, Best Loss: 0.08209096933475471, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 356/500, Loss: 0.08141148203425834, Best Loss: 0.08187246093928324, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 357/500, Loss: 0.08097187748240847, Best Loss: 0.08141148203425834, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 358/500, Loss: 0.08067913713892765, Best Loss: 0.08097187748240847, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 359/500, Loss: 0.08055644562098303, Best Loss: 0.08067913713892765, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 360/500, Loss: 0.08053939790499968, Best Loss: 0.08055644562098303, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 361/500, Loss: 0.08050462013449547, Best Loss: 0.08053939790499968, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 362/500, Loss: 0.08088634263641949, Best Loss: 0.08050462013449547, LR: 0.0001
# Epoch 363/500, Loss: 0.08068773710606575, Best Loss: 0.08050462013449547, LR: 0.0001
# Epoch 364/500, Loss: 0.08035982140229989, Best Loss: 0.08050462013449547, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 365/500, Loss: 0.08025532325031538, Best Loss: 0.08035982140229989, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 366/500, Loss: 0.08014506894017627, Best Loss: 0.08025532325031538, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 367/500, Loss: 0.08016369080793481, Best Loss: 0.08014506894017627, LR: 0.0001
# Epoch 368/500, Loss: 0.0799050418860563, Best Loss: 0.08014506894017627, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 369/500, Loss: 0.07989179756906298, Best Loss: 0.0799050418860563, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 370/500, Loss: 0.0797248876976132, Best Loss: 0.07989179756906298, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 371/500, Loss: 0.07980167588087783, Best Loss: 0.0797248876976132, LR: 0.0001
# Epoch 372/500, Loss: 0.07949327139874016, Best Loss: 0.0797248876976132, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 373/500, Loss: 0.0793153582276898, Best Loss: 0.07949327139874016, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 374/500, Loss: 0.07909009147916993, Best Loss: 0.0793153582276898, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 375/500, Loss: 0.07921434258273088, Best Loss: 0.07909009147916993, LR: 0.0001
# Epoch 376/500, Loss: 0.07902972140561643, Best Loss: 0.07909009147916993, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 377/500, Loss: 0.07930447083889433, Best Loss: 0.07902972140561643, LR: 0.0001
# Epoch 378/500, Loss: 0.07895305454795411, Best Loss: 0.07902972140561643, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 379/500, Loss: 0.0789303550383151, Best Loss: 0.07895305454795411, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 380/500, Loss: 0.07861974078097284, Best Loss: 0.0789303550383151, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 381/500, Loss: 0.07858576170111238, Best Loss: 0.07861974078097284, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 382/500, Loss: 0.07901981074187439, Best Loss: 0.07858576170111238, LR: 0.0001
# Epoch 383/500, Loss: 0.07939575043041058, Best Loss: 0.07858576170111238, LR: 0.0001
# Epoch 384/500, Loss: 0.07883746421767476, Best Loss: 0.07858576170111238, LR: 0.0001
# Epoch 385/500, Loss: 0.07853241994094395, Best Loss: 0.07858576170111238, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 386/500, Loss: 0.07819594334290753, Best Loss: 0.07853241994094395, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 387/500, Loss: 0.07810855272253818, Best Loss: 0.07819594334290753, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 388/500, Loss: 0.0786526561124831, Best Loss: 0.07810855272253818, LR: 0.0001
# Epoch 389/500, Loss: 0.07813223463616431, Best Loss: 0.07810855272253818, LR: 0.0001
# Epoch 390/500, Loss: 0.07885388884060424, Best Loss: 0.07810855272253818, LR: 0.0001
# Epoch 391/500, Loss: 0.07810737444848866, Best Loss: 0.07810855272253818, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 392/500, Loss: 0.07827379763564453, Best Loss: 0.07810737444848866, LR: 0.0001
# Epoch 393/500, Loss: 0.07781912154170584, Best Loss: 0.07810737444848866, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 394/500, Loss: 0.07753000018004468, Best Loss: 0.07781912154170584, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 395/500, Loss: 0.07727686032633528, Best Loss: 0.07753000018004468, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 396/500, Loss: 0.07796680905050496, Best Loss: 0.07727686032633528, LR: 0.0001
# Epoch 397/500, Loss: 0.07738277386637205, Best Loss: 0.07727686032633528, LR: 0.0001
# Epoch 398/500, Loss: 0.07739402266791823, Best Loss: 0.07727686032633528, LR: 0.0001
# Epoch 399/500, Loss: 0.07717803430168133, Best Loss: 0.07727686032633528, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 400/500, Loss: 0.07720308203912121, Best Loss: 0.07717803430168133, LR: 0.0001
# Epoch 401/500, Loss: 0.07716558278057929, Best Loss: 0.07717803430168133, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 402/500, Loss: 0.0769055348342237, Best Loss: 0.07716558278057929, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 403/500, Loss: 0.0767965314453214, Best Loss: 0.0769055348342237, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 404/500, Loss: 0.07673141783867571, Best Loss: 0.0767965314453214, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 405/500, Loss: 0.0764674965020026, Best Loss: 0.07673141783867571, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 406/500, Loss: 0.07628842828158326, Best Loss: 0.0764674965020026, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 407/500, Loss: 0.07626675197534936, Best Loss: 0.07628842828158326, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 408/500, Loss: 0.07658650455823256, Best Loss: 0.07626675197534936, LR: 0.0001
# Epoch 409/500, Loss: 0.0763382960837278, Best Loss: 0.07626675197534936, LR: 0.0001
# Epoch 410/500, Loss: 0.0760770467803739, Best Loss: 0.07626675197534936, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 411/500, Loss: 0.07618827602459248, Best Loss: 0.0760770467803739, LR: 0.0001
# Epoch 412/500, Loss: 0.07691910031214969, Best Loss: 0.0760770467803739, LR: 0.0001
# Epoch 413/500, Loss: 0.07617965282311029, Best Loss: 0.0760770467803739, LR: 0.0001
# Epoch 414/500, Loss: 0.07615407234822008, Best Loss: 0.0760770467803739, LR: 0.0001
# Epoch 415/500, Loss: 0.07598361240235232, Best Loss: 0.0760770467803739, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 416/500, Loss: 0.07557522798326692, Best Loss: 0.07598361240235232, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 417/500, Loss: 0.07583820832739441, Best Loss: 0.07557522798326692, LR: 0.0001
# Epoch 418/500, Loss: 0.07638281629204595, Best Loss: 0.07557522798326692, LR: 0.0001
# Epoch 419/500, Loss: 0.07609085240665062, Best Loss: 0.07557522798326692, LR: 0.0001
# Epoch 420/500, Loss: 0.07568716501653633, Best Loss: 0.07557522798326692, LR: 0.0001
# Epoch 421/500, Loss: 0.07540364447341716, Best Loss: 0.07557522798326692, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 422/500, Loss: 0.07512088798685503, Best Loss: 0.07540364447341716, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 423/500, Loss: 0.07520491491972602, Best Loss: 0.07512088798685503, LR: 0.0001
# Epoch 424/500, Loss: 0.07491237557764131, Best Loss: 0.07512088798685503, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 425/500, Loss: 0.07486902711726967, Best Loss: 0.07491237557764131, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 426/500, Loss: 0.07467236731908458, Best Loss: 0.07486902711726967, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 427/500, Loss: 0.07453580783382928, Best Loss: 0.07467236731908458, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 428/500, Loss: 0.07444299515248169, Best Loss: 0.07453580783382928, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 429/500, Loss: 0.0744595584792592, Best Loss: 0.07444299515248169, LR: 0.0001
# Epoch 430/500, Loss: 0.07439930269625916, Best Loss: 0.07444299515248169, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 431/500, Loss: 0.0743081287367747, Best Loss: 0.07439930269625916, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 432/500, Loss: 0.07418856157454587, Best Loss: 0.0743081287367747, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 433/500, Loss: 0.07419300521935315, Best Loss: 0.07418856157454587, LR: 0.0001
# Epoch 434/500, Loss: 0.07404797251702283, Best Loss: 0.07418856157454587, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 435/500, Loss: 0.07471519837158354, Best Loss: 0.07404797251702283, LR: 0.0001
# Epoch 436/500, Loss: 0.07446108090377607, Best Loss: 0.07404797251702283, LR: 0.0001
# Epoch 437/500, Loss: 0.07455424560170332, Best Loss: 0.07404797251702283, LR: 0.0001
# Epoch 438/500, Loss: 0.07404997913103262, Best Loss: 0.07404797251702283, LR: 0.0001
# Epoch 439/500, Loss: 0.07374069060191313, Best Loss: 0.07404797251702283, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 440/500, Loss: 0.07366610316167495, Best Loss: 0.07374069060191313, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 441/500, Loss: 0.07362089150855411, Best Loss: 0.07366610316167495, LR: 0.0001
# Saved best model to MLP_15to1_s32.pth
# Epoch 442/500, Loss: 0.0750738242894759, Best Loss: 0.07362089150855411, LR: 0.0001
# Epoch 443/500, Loss: 0.07746900766572548, Best Loss: 0.07362089150855411, LR: 0.0001
# Epoch 444/500, Loss: 0.07680446027395171, Best Loss: 0.07362089150855411, LR: 0.0001
# Epoch 445/500, Loss: 0.07763817532723258, Best Loss: 0.07362089150855411, LR: 0.0001
# Epoch 446/500, Loss: 0.07569592339467858, Best Loss: 0.07362089150855411, LR: 0.0001
# Epoch 447/500, Loss: 0.07453295005782569, Best Loss: 0.07362089150855411, LR: 1e-05
# Epoch 448/500, Loss: 0.07333407471487134, Best Loss: 0.07362089150855411, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 449/500, Loss: 0.07252717011685089, Best Loss: 0.07333407471487134, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 450/500, Loss: 0.07238240104202476, Best Loss: 0.07252717011685089, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 451/500, Loss: 0.07228225464113233, Best Loss: 0.07238240104202476, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 452/500, Loss: 0.07225529794769271, Best Loss: 0.07228225464113233, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 453/500, Loss: 0.07220066856098444, Best Loss: 0.07225529794769271, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 454/500, Loss: 0.07217350248786931, Best Loss: 0.07220066856098444, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 455/500, Loss: 0.0721424729359959, Best Loss: 0.07217350248786931, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 456/500, Loss: 0.07213202977317058, Best Loss: 0.0721424729359959, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 457/500, Loss: 0.07211425584461903, Best Loss: 0.07213202977317058, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 458/500, Loss: 0.07209874840007939, Best Loss: 0.07211425584461903, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 459/500, Loss: 0.07208222973168901, Best Loss: 0.07209874840007939, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 460/500, Loss: 0.07206156484579762, Best Loss: 0.07208222973168901, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 461/500, Loss: 0.0720509276135474, Best Loss: 0.07206156484579762, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 462/500, Loss: 0.07203706846420661, Best Loss: 0.0720509276135474, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 463/500, Loss: 0.07201501434299269, Best Loss: 0.07203706846420661, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 464/500, Loss: 0.07199537920271531, Best Loss: 0.07201501434299269, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 465/500, Loss: 0.07197920716831914, Best Loss: 0.07199537920271531, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 466/500, Loss: 0.07197572680337574, Best Loss: 0.07197920716831914, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 467/500, Loss: 0.07196416760606782, Best Loss: 0.07197572680337574, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 468/500, Loss: 0.07194623976005293, Best Loss: 0.07196416760606782, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 469/500, Loss: 0.07194074179527825, Best Loss: 0.07194623976005293, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 470/500, Loss: 0.07192266422577148, Best Loss: 0.07194074179527825, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 471/500, Loss: 0.07192095016703892, Best Loss: 0.07192266422577148, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 472/500, Loss: 0.07192724648101269, Best Loss: 0.07192095016703892, LR: 1e-05
# Epoch 473/500, Loss: 0.07190673030394266, Best Loss: 0.07192095016703892, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 474/500, Loss: 0.07189138468807516, Best Loss: 0.07190673030394266, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 475/500, Loss: 0.0718748052489742, Best Loss: 0.07189138468807516, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 476/500, Loss: 0.07186910635044809, Best Loss: 0.0718748052489742, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 477/500, Loss: 0.07187640011452309, Best Loss: 0.07186910635044809, LR: 1e-05
# Epoch 478/500, Loss: 0.0718509597672408, Best Loss: 0.07186910635044809, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 479/500, Loss: 0.07184103981362655, Best Loss: 0.0718509597672408, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 480/500, Loss: 0.07183465367393271, Best Loss: 0.07184103981362655, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 481/500, Loss: 0.07181488588239741, Best Loss: 0.07183465367393271, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 482/500, Loss: 0.07180678551969104, Best Loss: 0.07181488588239741, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 483/500, Loss: 0.07180389013967625, Best Loss: 0.07180678551969104, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 484/500, Loss: 0.07179000256345533, Best Loss: 0.07180389013967625, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 485/500, Loss: 0.07177183809949884, Best Loss: 0.07179000256345533, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 486/500, Loss: 0.07177394496456556, Best Loss: 0.07177183809949884, LR: 1e-05
# Epoch 487/500, Loss: 0.07177228197113962, Best Loss: 0.07177183809949884, LR: 1e-05
# Epoch 488/500, Loss: 0.0717577210209146, Best Loss: 0.07177183809949884, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 489/500, Loss: 0.07174313993189585, Best Loss: 0.0717577210209146, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 490/500, Loss: 0.07173042991462333, Best Loss: 0.07174313993189585, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 491/500, Loss: 0.0717192853664455, Best Loss: 0.07173042991462333, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 492/500, Loss: 0.07171969872710512, Best Loss: 0.0717192853664455, LR: 1e-05
# Epoch 493/500, Loss: 0.07170414697528658, Best Loss: 0.0717192853664455, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 494/500, Loss: 0.07169879664668159, Best Loss: 0.07170414697528658, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 495/500, Loss: 0.07168980578980919, Best Loss: 0.07169879664668159, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 496/500, Loss: 0.0716763118864188, Best Loss: 0.07168980578980919, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 497/500, Loss: 0.07166739476227008, Best Loss: 0.0716763118864188, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 498/500, Loss: 0.0716643593061862, Best Loss: 0.07166739476227008, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 499/500, Loss: 0.0716508626551325, Best Loss: 0.0716643593061862, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth
# Epoch 500/500, Loss: 0.07164058553105662, Best Loss: 0.0716508626551325, LR: 1e-05
# Saved best model to MLP_15to1_s32.pth

# %%
model_class.train_multi(epochs=500, save_path='MLP_15to1_s32_multi_3.pth', patience=10, lr_=0.0001, batch_size_=128, train_steps=9, load_weights='MLP_15to1_s32.pth')
# Out:
# Training on cpu
# Epoch 1/500, Loss: 4.65975535838469, Best Loss: inf, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 2/500, Loss: 2.2304596600468622, Best Loss: 4.65975535838469, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 3/500, Loss: 1.8488899350836325, Best Loss: 2.2304596600468622, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 4/500, Loss: 1.6898175518697234, Best Loss: 1.8488899350836325, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 5/500, Loss: 1.566158111714925, Best Loss: 1.6898175518697234, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 6/500, Loss: 1.5171797834224017, Best Loss: 1.566158111714925, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 7/500, Loss: 1.4622783386702152, Best Loss: 1.5171797834224017, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 8/500, Loss: 1.4235697231713282, Best Loss: 1.4622783386702152, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 9/500, Loss: 1.4105582579976803, Best Loss: 1.4235697231713282, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 10/500, Loss: 1.3572412811210028, Best Loss: 1.4105582579976803, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 11/500, Loss: 1.347541943392195, Best Loss: 1.3572412811210028, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 12/500, Loss: 1.3199871749111032, Best Loss: 1.347541943392195, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 13/500, Loss: 1.334908245138621, Best Loss: 1.3199871749111032, LR: 0.0001
# Epoch 14/500, Loss: 1.332564881958077, Best Loss: 1.3199871749111032, LR: 0.0001
# Epoch 15/500, Loss: 1.2827776204545005, Best Loss: 1.3199871749111032, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 16/500, Loss: 1.3592304284573633, Best Loss: 1.2827776204545005, LR: 0.0001
# Epoch 17/500, Loss: 1.268265372326608, Best Loss: 1.2827776204545005, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 18/500, Loss: 1.2779475432992549, Best Loss: 1.268265372326608, LR: 0.0001
# Epoch 19/500, Loss: 1.250309280796686, Best Loss: 1.268265372326608, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 20/500, Loss: 1.2669646320949115, Best Loss: 1.250309280796686, LR: 0.0001
# Epoch 21/500, Loss: 1.2229992598101942, Best Loss: 1.250309280796686, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 22/500, Loss: 1.2148204680598251, Best Loss: 1.2229992598101942, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 23/500, Loss: 1.2170527028769473, Best Loss: 1.2148204680598251, LR: 0.0001
# Epoch 24/500, Loss: 1.2096568989743415, Best Loss: 1.2148204680598251, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 25/500, Loss: 1.2239559512090952, Best Loss: 1.2096568989743415, LR: 0.0001
# Epoch 26/500, Loss: 1.2210291905986557, Best Loss: 1.2096568989743415, LR: 0.0001
# Epoch 27/500, Loss: 1.1847114097077354, Best Loss: 1.2096568989743415, LR: 0.0001
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 28/500, Loss: 1.1921826902530537, Best Loss: 1.1847114097077354, LR: 0.0001
# Epoch 29/500, Loss: 1.1965435689216148, Best Loss: 1.1847114097077354, LR: 0.0001
# Epoch 30/500, Loss: 1.185727805891338, Best Loss: 1.1847114097077354, LR: 0.0001
# Epoch 31/500, Loss: 1.1992392052936183, Best Loss: 1.1847114097077354, LR: 1e-05
# Epoch 32/500, Loss: 1.192165086447703, Best Loss: 1.1847114097077354, LR: 1e-05
# Epoch 33/500, Loss: 1.0746050937527245, Best Loss: 1.1847114097077354, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 34/500, Loss: 1.0583706432949451, Best Loss: 1.0746050937527245, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 35/500, Loss: 1.0537749100597298, Best Loss: 1.0583706432949451, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 36/500, Loss: 1.0506191092860993, Best Loss: 1.0537749100597298, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 37/500, Loss: 1.0487945134434615, Best Loss: 1.0506191092860993, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 38/500, Loss: 1.046052260209202, Best Loss: 1.0487945134434615, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 39/500, Loss: 1.0431864066295071, Best Loss: 1.046052260209202, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 40/500, Loss: 1.041881203702967, Best Loss: 1.0431864066295071, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 41/500, Loss: 1.0401815881061183, Best Loss: 1.041881203702967, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 42/500, Loss: 1.0380455134392197, Best Loss: 1.0401815881061183, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 43/500, Loss: 1.0359547676279388, Best Loss: 1.0380455134392197, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 44/500, Loss: 1.0351043564903237, Best Loss: 1.0359547676279388, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 45/500, Loss: 1.0329123784905123, Best Loss: 1.0351043564903237, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 46/500, Loss: 1.0314704778644876, Best Loss: 1.0329123784905123, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 47/500, Loss: 1.0303464288635271, Best Loss: 1.0314704778644876, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 48/500, Loss: 1.0299092961553367, Best Loss: 1.0303464288635271, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 49/500, Loss: 1.0276993395083402, Best Loss: 1.0299092961553367, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 50/500, Loss: 1.0252821618120134, Best Loss: 1.0276993395083402, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 51/500, Loss: 1.0251673634207923, Best Loss: 1.0252821618120134, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 52/500, Loss: 1.0241920043522281, Best Loss: 1.0251673634207923, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 53/500, Loss: 1.0211070045165258, Best Loss: 1.0241920043522281, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 54/500, Loss: 1.0219658637428202, Best Loss: 1.0211070045165258, LR: 1e-05
# Epoch 55/500, Loss: 1.020586276719233, Best Loss: 1.0211070045165258, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 56/500, Loss: 1.020126716172185, Best Loss: 1.020586276719233, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 57/500, Loss: 1.0172580886186071, Best Loss: 1.020126716172185, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 58/500, Loss: 1.0162654959480328, Best Loss: 1.0172580886186071, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 59/500, Loss: 1.0144101080315173, Best Loss: 1.0162654959480328, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 60/500, Loss: 1.015392115247028, Best Loss: 1.0144101080315173, LR: 1e-05
# Epoch 61/500, Loss: 1.0135943139470402, Best Loss: 1.0144101080315173, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 62/500, Loss: 1.0127751209804932, Best Loss: 1.0135943139470402, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 63/500, Loss: 1.0108847757773227, Best Loss: 1.0127751209804932, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 64/500, Loss: 1.010340519246218, Best Loss: 1.0108847757773227, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 65/500, Loss: 1.0083145605657093, Best Loss: 1.010340519246218, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 66/500, Loss: 1.0075891041621676, Best Loss: 1.0083145605657093, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 67/500, Loss: 1.0060918318261536, Best Loss: 1.0075891041621676, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 68/500, Loss: 1.0047465805825968, Best Loss: 1.0060918318261536, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 69/500, Loss: 1.0044317806225755, Best Loss: 1.0047465805825968, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 70/500, Loss: 1.0025899319281786, Best Loss: 1.0044317806225755, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 71/500, Loss: 1.0015723673853067, Best Loss: 1.0025899319281786, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 72/500, Loss: 1.0003569071498002, Best Loss: 1.0015723673853067, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 73/500, Loss: 1.000239315148406, Best Loss: 1.0003569071498002, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 74/500, Loss: 1.0007501999846382, Best Loss: 1.000239315148406, LR: 1e-05
# Epoch 75/500, Loss: 0.9981250585388219, Best Loss: 1.000239315148406, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 76/500, Loss: 0.9967189088715035, Best Loss: 0.9981250585388219, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 77/500, Loss: 0.9954751091914624, Best Loss: 0.9967189088715035, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 78/500, Loss: 0.994935373078679, Best Loss: 0.9954751091914624, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 79/500, Loss: 0.9936698795756478, Best Loss: 0.994935373078679, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 80/500, Loss: 0.9932289843790159, Best Loss: 0.9936698795756478, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 81/500, Loss: 0.9926517784363564, Best Loss: 0.9932289843790159, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 82/500, Loss: 0.9912016989604456, Best Loss: 0.9926517784363564, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 83/500, Loss: 0.9909666782841763, Best Loss: 0.9912016989604456, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 84/500, Loss: 0.9904338904288853, Best Loss: 0.9909666782841763, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 85/500, Loss: 0.9889098601685526, Best Loss: 0.9904338904288853, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 86/500, Loss: 0.9886259231225165, Best Loss: 0.9889098601685526, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 87/500, Loss: 0.9875748561307872, Best Loss: 0.9886259231225165, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 88/500, Loss: 0.9871699110130907, Best Loss: 0.9875748561307872, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 89/500, Loss: 0.9852897308370637, Best Loss: 0.9871699110130907, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 90/500, Loss: 0.9839176864166359, Best Loss: 0.9852897308370637, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 91/500, Loss: 0.9831278879200284, Best Loss: 0.9839176864166359, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 92/500, Loss: 0.9834413444949495, Best Loss: 0.9831278879200284, LR: 1e-05
# Epoch 93/500, Loss: 0.9819785352398501, Best Loss: 0.9831278879200284, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 94/500, Loss: 0.9819020018967209, Best Loss: 0.9819785352398501, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 95/500, Loss: 0.9810804071438761, Best Loss: 0.9819020018967209, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 96/500, Loss: 0.9793458614213303, Best Loss: 0.9810804071438761, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 97/500, Loss: 0.9780783657897771, Best Loss: 0.9793458614213303, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 98/500, Loss: 0.9772420961053867, Best Loss: 0.9780783657897771, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 99/500, Loss: 0.9764206335238446, Best Loss: 0.9772420961053867, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 100/500, Loss: 0.9767725374138927, Best Loss: 0.9764206335238446, LR: 1e-05
# Epoch 101/500, Loss: 0.9748417395201278, Best Loss: 0.9764206335238446, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 102/500, Loss: 0.9735415662669847, Best Loss: 0.9748417395201278, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 103/500, Loss: 0.9728838141429388, Best Loss: 0.9735415662669847, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 104/500, Loss: 0.9728566217463717, Best Loss: 0.9728838141429388, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 105/500, Loss: 0.9718587500575916, Best Loss: 0.9728566217463717, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 106/500, Loss: 0.9709417369012135, Best Loss: 0.9718587500575916, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 107/500, Loss: 0.9705834151138952, Best Loss: 0.9709417369012135, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 108/500, Loss: 0.9699815904429296, Best Loss: 0.9705834151138952, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 109/500, Loss: 0.9684302598637418, Best Loss: 0.9699815904429296, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 110/500, Loss: 0.9680320061856, Best Loss: 0.9684302598637418, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 111/500, Loss: 0.9670728409491315, Best Loss: 0.9680320061856, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 112/500, Loss: 0.966491044108815, Best Loss: 0.9670728409491315, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 113/500, Loss: 0.9653206028775431, Best Loss: 0.966491044108815, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 114/500, Loss: 0.9646626013571495, Best Loss: 0.9653206028775431, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 115/500, Loss: 0.964169140404249, Best Loss: 0.9646626013571495, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 116/500, Loss: 0.963975930183005, Best Loss: 0.964169140404249, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 117/500, Loss: 0.9627244368395247, Best Loss: 0.963975930183005, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 118/500, Loss: 0.9643391367165598, Best Loss: 0.9627244368395247, LR: 1e-05
# Epoch 119/500, Loss: 0.9622201308820653, Best Loss: 0.9627244368395247, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 120/500, Loss: 0.9605049915866217, Best Loss: 0.9622201308820653, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 121/500, Loss: 0.959337598670369, Best Loss: 0.9605049915866217, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 122/500, Loss: 0.9601159033659883, Best Loss: 0.959337598670369, LR: 1e-05
# Epoch 123/500, Loss: 0.9594873659960181, Best Loss: 0.959337598670369, LR: 1e-05
# Epoch 124/500, Loss: 0.9586776684642714, Best Loss: 0.959337598670369, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 125/500, Loss: 0.958352367547081, Best Loss: 0.9586776684642714, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 126/500, Loss: 0.9572175055471684, Best Loss: 0.958352367547081, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 127/500, Loss: 0.9559721428751172, Best Loss: 0.9572175055471684, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 128/500, Loss: 0.9556991122163738, Best Loss: 0.9559721428751172, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 129/500, Loss: 0.955819110152941, Best Loss: 0.9556991122163738, LR: 1e-05
# Epoch 130/500, Loss: 0.9557562249592254, Best Loss: 0.9556991122163738, LR: 1e-05
# Epoch 131/500, Loss: 0.9542136734510158, Best Loss: 0.9556991122163738, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 132/500, Loss: 0.9536765874901015, Best Loss: 0.9542136734510158, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 133/500, Loss: 0.9528082813270361, Best Loss: 0.9536765874901015, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 134/500, Loss: 0.9524335557384713, Best Loss: 0.9528082813270361, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 135/500, Loss: 0.9515919981711982, Best Loss: 0.9524335557384713, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 136/500, Loss: 0.9515311757671951, Best Loss: 0.9515919981711982, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 137/500, Loss: 0.9494924194051031, Best Loss: 0.9515311757671951, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 138/500, Loss: 0.9499978401729982, Best Loss: 0.9494924194051031, LR: 1e-05
# Epoch 139/500, Loss: 0.9496918844290229, Best Loss: 0.9494924194051031, LR: 1e-05
# Epoch 140/500, Loss: 0.9480970369960341, Best Loss: 0.9494924194051031, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 141/500, Loss: 0.9478199885513068, Best Loss: 0.9480970369960341, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 142/500, Loss: 0.9477790271983331, Best Loss: 0.9478199885513068, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 143/500, Loss: 0.9462000684618589, Best Loss: 0.9477790271983331, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 144/500, Loss: 0.9457193139926005, Best Loss: 0.9462000684618589, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 145/500, Loss: 0.9461013216813612, Best Loss: 0.9457193139926005, LR: 1e-05
# Epoch 146/500, Loss: 0.9447495807984975, Best Loss: 0.9457193139926005, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 147/500, Loss: 0.9446130132345323, Best Loss: 0.9447495807984975, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 148/500, Loss: 0.9442195157905806, Best Loss: 0.9446130132345323, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 149/500, Loss: 0.9431508008247322, Best Loss: 0.9442195157905806, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 150/500, Loss: 0.9419022489047597, Best Loss: 0.9431508008247322, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 151/500, Loss: 0.9422192983023284, Best Loss: 0.9419022489047597, LR: 1e-05
# Epoch 152/500, Loss: 0.9423506208379393, Best Loss: 0.9419022489047597, LR: 1e-05
# Epoch 153/500, Loss: 0.9416355878514127, Best Loss: 0.9419022489047597, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 154/500, Loss: 0.9402330038200144, Best Loss: 0.9416355878514127, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 155/500, Loss: 0.9401792890315338, Best Loss: 0.9402330038200144, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 156/500, Loss: 0.9390444354839877, Best Loss: 0.9401792890315338, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 157/500, Loss: 0.9391497917315479, Best Loss: 0.9390444354839877, LR: 1e-05
# Epoch 158/500, Loss: 0.9398999331938566, Best Loss: 0.9390444354839877, LR: 1e-05
# Epoch 159/500, Loss: 0.9380532300065103, Best Loss: 0.9390444354839877, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 160/500, Loss: 0.9382048312895132, Best Loss: 0.9380532300065103, LR: 1e-05
# Epoch 161/500, Loss: 0.9388041665581878, Best Loss: 0.9380532300065103, LR: 1e-05
# Epoch 162/500, Loss: 0.9358346128278205, Best Loss: 0.9380532300065103, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 163/500, Loss: 0.9362506719569442, Best Loss: 0.9358346128278205, LR: 1e-05
# Epoch 164/500, Loss: 0.935328238565995, Best Loss: 0.9358346128278205, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 165/500, Loss: 0.9353277163746756, Best Loss: 0.935328238565995, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 166/500, Loss: 0.9337403253977091, Best Loss: 0.9353277163746756, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 167/500, Loss: 0.9334868584367758, Best Loss: 0.9337403253977091, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 168/500, Loss: 0.9324908896127512, Best Loss: 0.9334868584367758, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 169/500, Loss: 0.9330469147240605, Best Loss: 0.9324908896127512, LR: 1e-05
# Epoch 170/500, Loss: 0.9318426886112, Best Loss: 0.9324908896127512, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 171/500, Loss: 0.930804428603811, Best Loss: 0.9318426886112, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 172/500, Loss: 0.9312913393077529, Best Loss: 0.930804428603811, LR: 1e-05
# Epoch 173/500, Loss: 0.9308906532807933, Best Loss: 0.930804428603811, LR: 1e-05
# Epoch 174/500, Loss: 0.9294035301237358, Best Loss: 0.930804428603811, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 175/500, Loss: 0.9290392260710192, Best Loss: 0.9294035301237358, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 176/500, Loss: 0.9291340060116561, Best Loss: 0.9290392260710192, LR: 1e-05
# Epoch 177/500, Loss: 0.9279658718125623, Best Loss: 0.9290392260710192, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 178/500, Loss: 0.9272947493075706, Best Loss: 0.9279658718125623, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 179/500, Loss: 0.927649364165295, Best Loss: 0.9272947493075706, LR: 1e-05
# Epoch 180/500, Loss: 0.9264797044944516, Best Loss: 0.9272947493075706, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 181/500, Loss: 0.9262243250567729, Best Loss: 0.9264797044944516, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 182/500, Loss: 0.9257574052043771, Best Loss: 0.9262243250567729, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 183/500, Loss: 0.9247462157557859, Best Loss: 0.9257574052043771, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 184/500, Loss: 0.9258877384265779, Best Loss: 0.9247462157557859, LR: 1e-05
# Epoch 185/500, Loss: 0.9245277626711313, Best Loss: 0.9247462157557859, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 186/500, Loss: 0.9234942506774906, Best Loss: 0.9245277626711313, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 187/500, Loss: 0.9234386607263699, Best Loss: 0.9234942506774906, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 188/500, Loss: 0.9223757268956766, Best Loss: 0.9234386607263699, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 189/500, Loss: 0.921988965936208, Best Loss: 0.9223757268956766, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 190/500, Loss: 0.9217302936833501, Best Loss: 0.921988965936208, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 191/500, Loss: 0.9213304463476008, Best Loss: 0.9217302936833501, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 192/500, Loss: 0.9203357758379787, Best Loss: 0.9213304463476008, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 193/500, Loss: 0.9207858746308452, Best Loss: 0.9203357758379787, LR: 1e-05
# Epoch 194/500, Loss: 0.9194600653246374, Best Loss: 0.9203357758379787, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 195/500, Loss: 0.9195886118505818, Best Loss: 0.9194600653246374, LR: 1e-05
# Epoch 196/500, Loss: 0.9188822848529873, Best Loss: 0.9194600653246374, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 197/500, Loss: 0.9193604245517762, Best Loss: 0.9188822848529873, LR: 1e-05
# Epoch 198/500, Loss: 0.9188559288799222, Best Loss: 0.9188822848529873, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 199/500, Loss: 0.9172870413441705, Best Loss: 0.9188559288799222, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 200/500, Loss: 0.9167412845695684, Best Loss: 0.9172870413441705, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 201/500, Loss: 0.9175439088621853, Best Loss: 0.9167412845695684, LR: 1e-05
# Epoch 202/500, Loss: 0.9168071855573081, Best Loss: 0.9167412845695684, LR: 1e-05
# Epoch 203/500, Loss: 0.9157790941074716, Best Loss: 0.9167412845695684, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 204/500, Loss: 0.9155883312328419, Best Loss: 0.9157790941074716, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 205/500, Loss: 0.9154207138493625, Best Loss: 0.9155883312328419, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 206/500, Loss: 0.9155369232188455, Best Loss: 0.9154207138493625, LR: 1e-05
# Epoch 207/500, Loss: 0.9176884703289828, Best Loss: 0.9154207138493625, LR: 1e-05
# Epoch 208/500, Loss: 0.9133761195563362, Best Loss: 0.9154207138493625, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 209/500, Loss: 0.9132086446003845, Best Loss: 0.9133761195563362, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 210/500, Loss: 0.9130401154178795, Best Loss: 0.9132086446003845, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 211/500, Loss: 0.9121114218899866, Best Loss: 0.9130401154178795, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 212/500, Loss: 0.9121029402237664, Best Loss: 0.9121114218899866, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 213/500, Loss: 0.9114128201233583, Best Loss: 0.9121029402237664, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 214/500, Loss: 0.9112876113029048, Best Loss: 0.9114128201233583, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 215/500, Loss: 0.9107695844747574, Best Loss: 0.9112876113029048, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 216/500, Loss: 0.9107495173972971, Best Loss: 0.9107695844747574, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 217/500, Loss: 0.9103485588072906, Best Loss: 0.9107495173972971, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 218/500, Loss: 0.9103163448289211, Best Loss: 0.9103485588072906, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 219/500, Loss: 0.9090818294291366, Best Loss: 0.9103163448289211, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 220/500, Loss: 0.9098186393965388, Best Loss: 0.9090818294291366, LR: 1e-05
# Epoch 221/500, Loss: 0.9089894513778752, Best Loss: 0.9090818294291366, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 222/500, Loss: 0.9084986979910887, Best Loss: 0.9089894513778752, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 223/500, Loss: 0.9082026982585744, Best Loss: 0.9084986979910887, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 224/500, Loss: 0.9083197343880307, Best Loss: 0.9082026982585744, LR: 1e-05
# Epoch 225/500, Loss: 0.9071905014837556, Best Loss: 0.9082026982585744, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 226/500, Loss: 0.9068251630211619, Best Loss: 0.9071905014837556, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 227/500, Loss: 0.9068782343990196, Best Loss: 0.9068251630211619, LR: 1e-05
# Epoch 228/500, Loss: 0.9059918623077782, Best Loss: 0.9068251630211619, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 229/500, Loss: 0.9064126755580003, Best Loss: 0.9059918623077782, LR: 1e-05
# Epoch 230/500, Loss: 0.904428620720858, Best Loss: 0.9059918623077782, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 231/500, Loss: 0.9038782781251725, Best Loss: 0.904428620720858, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 232/500, Loss: 0.9040025556391573, Best Loss: 0.9038782781251725, LR: 1e-05
# Epoch 233/500, Loss: 0.9034420032548637, Best Loss: 0.9038782781251725, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 234/500, Loss: 0.9050088860078441, Best Loss: 0.9034420032548637, LR: 1e-05
# Epoch 235/500, Loss: 0.9023009646366645, Best Loss: 0.9034420032548637, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 236/500, Loss: 0.9031275679577597, Best Loss: 0.9023009646366645, LR: 1e-05
# Epoch 237/500, Loss: 0.9023754568879242, Best Loss: 0.9023009646366645, LR: 1e-05
# Epoch 238/500, Loss: 0.9022635460363752, Best Loss: 0.9023009646366645, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 239/500, Loss: 0.9019345288868338, Best Loss: 0.9022635460363752, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 240/500, Loss: 0.901408571857835, Best Loss: 0.9019345288868338, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 241/500, Loss: 0.9013202793403359, Best Loss: 0.901408571857835, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 242/500, Loss: 0.9005404439675463, Best Loss: 0.9013202793403359, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 243/500, Loss: 0.8999398228826329, Best Loss: 0.9005404439675463, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 244/500, Loss: 0.8990554792562502, Best Loss: 0.8999398228826329, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 245/500, Loss: 0.8990841688039857, Best Loss: 0.8990554792562502, LR: 1e-05
# Epoch 246/500, Loss: 0.8982232968579419, Best Loss: 0.8990554792562502, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 247/500, Loss: 0.8988068582585916, Best Loss: 0.8982232968579419, LR: 1e-05
# Epoch 248/500, Loss: 0.8983107976618651, Best Loss: 0.8982232968579419, LR: 1e-05
# Epoch 249/500, Loss: 0.8975458836019478, Best Loss: 0.8982232968579419, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 250/500, Loss: 0.8974868247790405, Best Loss: 0.8975458836019478, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 251/500, Loss: 0.8972685919970699, Best Loss: 0.8974868247790405, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 252/500, Loss: 0.8987865980909441, Best Loss: 0.8972685919970699, LR: 1e-05
# Epoch 253/500, Loss: 0.8957533219445076, Best Loss: 0.8972685919970699, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 254/500, Loss: 0.8962250759062497, Best Loss: 0.8957533219445076, LR: 1e-05
# Epoch 255/500, Loss: 0.8959531297015773, Best Loss: 0.8957533219445076, LR: 1e-05
# Epoch 256/500, Loss: 0.8962496057300923, Best Loss: 0.8957533219445076, LR: 1e-05
# Epoch 257/500, Loss: 0.8951745077072156, Best Loss: 0.8957533219445076, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 258/500, Loss: 0.8945406403729166, Best Loss: 0.8951745077072156, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 259/500, Loss: 0.8954298808571585, Best Loss: 0.8945406403729166, LR: 1e-05
# Epoch 260/500, Loss: 0.8944559562170191, Best Loss: 0.8945406403729166, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 261/500, Loss: 0.8955971025771204, Best Loss: 0.8944559562170191, LR: 1e-05
# Epoch 262/500, Loss: 0.892994676196003, Best Loss: 0.8944559562170191, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 263/500, Loss: 0.8932984185022963, Best Loss: 0.892994676196003, LR: 1e-05
# Epoch 264/500, Loss: 0.8925248616915784, Best Loss: 0.892994676196003, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 265/500, Loss: 0.8919101429356675, Best Loss: 0.8925248616915784, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 266/500, Loss: 0.8919983085388237, Best Loss: 0.8919101429356675, LR: 1e-05
# Epoch 267/500, Loss: 0.8919113179692137, Best Loss: 0.8919101429356675, LR: 1e-05
# Epoch 268/500, Loss: 0.8915340690658147, Best Loss: 0.8919101429356675, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 269/500, Loss: 0.8908980658855266, Best Loss: 0.8915340690658147, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 270/500, Loss: 0.8904643132477368, Best Loss: 0.8908980658855266, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 271/500, Loss: 0.8901273503068511, Best Loss: 0.8904643132477368, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 272/500, Loss: 0.8901670810158924, Best Loss: 0.8901273503068511, LR: 1e-05
# Epoch 273/500, Loss: 0.8897261738622544, Best Loss: 0.8901273503068511, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 274/500, Loss: 0.8896141630769343, Best Loss: 0.8897261738622544, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 275/500, Loss: 0.8884957649983012, Best Loss: 0.8896141630769343, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 276/500, Loss: 0.8895176430311339, Best Loss: 0.8884957649983012, LR: 1e-05
# Epoch 277/500, Loss: 0.8884599427356382, Best Loss: 0.8884957649983012, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 278/500, Loss: 0.8875953483468157, Best Loss: 0.8884599427356382, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 279/500, Loss: 0.8875879908453269, Best Loss: 0.8875953483468157, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 280/500, Loss: 0.8870057041543004, Best Loss: 0.8875879908453269, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 281/500, Loss: 0.8866776447506421, Best Loss: 0.8870057041543004, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 282/500, Loss: 0.8867878960006638, Best Loss: 0.8866776447506421, LR: 1e-05
# Epoch 283/500, Loss: 0.8867581979155386, Best Loss: 0.8866776447506421, LR: 1e-05
# Epoch 284/500, Loss: 0.8855621970375018, Best Loss: 0.8866776447506421, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 285/500, Loss: 0.8851741229204507, Best Loss: 0.8855621970375018, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 286/500, Loss: 0.884944934866617, Best Loss: 0.8851741229204507, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 287/500, Loss: 0.8849778676569023, Best Loss: 0.884944934866617, LR: 1e-05
# Epoch 288/500, Loss: 0.884527842641856, Best Loss: 0.884944934866617, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 289/500, Loss: 0.8838817430325931, Best Loss: 0.884527842641856, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 290/500, Loss: 0.8831868521640479, Best Loss: 0.8838817430325931, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 291/500, Loss: 0.8833399065840672, Best Loss: 0.8831868521640479, LR: 1e-05
# Epoch 292/500, Loss: 0.8838592433228516, Best Loss: 0.8831868521640479, LR: 1e-05
# Epoch 293/500, Loss: 0.8824216340508648, Best Loss: 0.8831868521640479, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 294/500, Loss: 0.8822320891158487, Best Loss: 0.8824216340508648, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 295/500, Loss: 0.8822774247488211, Best Loss: 0.8822320891158487, LR: 1e-05
# Epoch 296/500, Loss: 0.8820584821742281, Best Loss: 0.8822320891158487, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 297/500, Loss: 0.8811822156858712, Best Loss: 0.8820584821742281, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 298/500, Loss: 0.8807493908499104, Best Loss: 0.8811822156858712, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 299/500, Loss: 0.8807437220951514, Best Loss: 0.8807493908499104, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 300/500, Loss: 0.880729117230631, Best Loss: 0.8807437220951514, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 301/500, Loss: 0.8793864594977808, Best Loss: 0.880729117230631, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 302/500, Loss: 0.8799577554066976, Best Loss: 0.8793864594977808, LR: 1e-05
# Epoch 303/500, Loss: 0.8791583389417464, Best Loss: 0.8793864594977808, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 304/500, Loss: 0.8788575508148186, Best Loss: 0.8791583389417464, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 305/500, Loss: 0.8784699031299602, Best Loss: 0.8788575508148186, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 306/500, Loss: 0.8777514088220839, Best Loss: 0.8784699031299602, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 307/500, Loss: 0.8783522646405508, Best Loss: 0.8777514088220839, LR: 1e-05
# Epoch 308/500, Loss: 0.8774872544365325, Best Loss: 0.8777514088220839, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 309/500, Loss: 0.8771335212276242, Best Loss: 0.8774872544365325, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 310/500, Loss: 0.8769122690696816, Best Loss: 0.8771335212276242, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 311/500, Loss: 0.8767414530066767, Best Loss: 0.8769122690696816, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 312/500, Loss: 0.876391089921177, Best Loss: 0.8767414530066767, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 313/500, Loss: 0.87653663304787, Best Loss: 0.876391089921177, LR: 1e-05
# Epoch 314/500, Loss: 0.8763695382680204, Best Loss: 0.876391089921177, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 315/500, Loss: 0.8755972958002779, Best Loss: 0.8763695382680204, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 316/500, Loss: 0.8749049297669621, Best Loss: 0.8755972958002779, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 317/500, Loss: 0.8747903530957428, Best Loss: 0.8749049297669621, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 318/500, Loss: 0.8748419337132458, Best Loss: 0.8747903530957428, LR: 1e-05
# Epoch 319/500, Loss: 0.8761361726063235, Best Loss: 0.8747903530957428, LR: 1e-05
# Epoch 320/500, Loss: 0.8743824710384159, Best Loss: 0.8747903530957428, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 321/500, Loss: 0.8729900734227712, Best Loss: 0.8743824710384159, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 322/500, Loss: 0.873777752952353, Best Loss: 0.8729900734227712, LR: 1e-05
# Epoch 323/500, Loss: 0.8728348303294728, Best Loss: 0.8729900734227712, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 324/500, Loss: 0.8733157110946085, Best Loss: 0.8728348303294728, LR: 1e-05
# Epoch 325/500, Loss: 0.8737228511990894, Best Loss: 0.8728348303294728, LR: 1e-05
# Epoch 326/500, Loss: 0.8720520809002887, Best Loss: 0.8728348303294728, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 327/500, Loss: 0.8718177495041917, Best Loss: 0.8720520809002887, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 328/500, Loss: 0.8722741642763127, Best Loss: 0.8718177495041917, LR: 1e-05
# Epoch 329/500, Loss: 0.8710307851272695, Best Loss: 0.8718177495041917, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 330/500, Loss: 0.8711273938713783, Best Loss: 0.8710307851272695, LR: 1e-05
# Epoch 331/500, Loss: 0.8701318745431682, Best Loss: 0.8710307851272695, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 332/500, Loss: 0.8708643606613067, Best Loss: 0.8701318745431682, LR: 1e-05
# Epoch 333/500, Loss: 0.8703250988087404, Best Loss: 0.8701318745431682, LR: 1e-05
# Epoch 334/500, Loss: 0.8698815754930849, Best Loss: 0.8701318745431682, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 335/500, Loss: 0.8696191303151746, Best Loss: 0.8698815754930849, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 336/500, Loss: 0.8705549484148615, Best Loss: 0.8696191303151746, LR: 1e-05
# Epoch 337/500, Loss: 0.8694215616363495, Best Loss: 0.8696191303151746, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 338/500, Loss: 0.869524266314723, Best Loss: 0.8694215616363495, LR: 1e-05
# Epoch 339/500, Loss: 0.8692575421520914, Best Loss: 0.8694215616363495, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 340/500, Loss: 0.8691568135493667, Best Loss: 0.8692575421520914, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 341/500, Loss: 0.8692033315343977, Best Loss: 0.8691568135493667, LR: 1e-05
# Epoch 342/500, Loss: 0.8682890867857103, Best Loss: 0.8691568135493667, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 343/500, Loss: 0.868501902013128, Best Loss: 0.8682890867857103, LR: 1e-05
# Epoch 344/500, Loss: 0.8681446180887877, Best Loss: 0.8682890867857103, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 345/500, Loss: 0.8667936832730615, Best Loss: 0.8681446180887877, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 346/500, Loss: 0.8667090912170344, Best Loss: 0.8667936832730615, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 347/500, Loss: 0.8668046700351433, Best Loss: 0.8667090912170344, LR: 1e-05
# Epoch 348/500, Loss: 0.8672728360446562, Best Loss: 0.8667090912170344, LR: 1e-05
# Epoch 349/500, Loss: 0.8664576650387376, Best Loss: 0.8667090912170344, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 350/500, Loss: 0.8661757517159887, Best Loss: 0.8664576650387376, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 351/500, Loss: 0.8659415480330863, Best Loss: 0.8661757517159887, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 352/500, Loss: 0.8659376034579955, Best Loss: 0.8659415480330863, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 353/500, Loss: 0.8648510457785986, Best Loss: 0.8659376034579955, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 354/500, Loss: 0.8648204089911841, Best Loss: 0.8648510457785986, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 355/500, Loss: 0.8644695573176752, Best Loss: 0.8648204089911841, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 356/500, Loss: 0.8646573213803217, Best Loss: 0.8644695573176752, LR: 1e-05
# Epoch 357/500, Loss: 0.8642508215425956, Best Loss: 0.8644695573176752, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 358/500, Loss: 0.863918883945846, Best Loss: 0.8642508215425956, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 359/500, Loss: 0.8635730691611689, Best Loss: 0.863918883945846, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 360/500, Loss: 0.8638386429000406, Best Loss: 0.8635730691611689, LR: 1e-05
# Epoch 361/500, Loss: 0.8625272790745538, Best Loss: 0.8635730691611689, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 362/500, Loss: 0.8630945387723588, Best Loss: 0.8625272790745538, LR: 1e-05
# Epoch 363/500, Loss: 0.8634730731054554, Best Loss: 0.8625272790745538, LR: 1e-05
# Epoch 364/500, Loss: 0.8639948002404585, Best Loss: 0.8625272790745538, LR: 1e-05
# Epoch 365/500, Loss: 0.8615981750915023, Best Loss: 0.8625272790745538, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 366/500, Loss: 0.8623048299017584, Best Loss: 0.8615981750915023, LR: 1e-05
# Epoch 367/500, Loss: 0.8622762018140652, Best Loss: 0.8615981750915023, LR: 1e-05
# Epoch 368/500, Loss: 0.8616068847139212, Best Loss: 0.8615981750915023, LR: 1e-05
# Epoch 369/500, Loss: 0.8607873001296542, Best Loss: 0.8615981750915023, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 370/500, Loss: 0.8607451349587034, Best Loss: 0.8607873001296542, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 371/500, Loss: 0.8604664993502595, Best Loss: 0.8607451349587034, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 372/500, Loss: 0.8602032770700285, Best Loss: 0.8604664993502595, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 373/500, Loss: 0.8599089081030721, Best Loss: 0.8602032770700285, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 374/500, Loss: 0.8609388880641029, Best Loss: 0.8599089081030721, LR: 1e-05
# Epoch 375/500, Loss: 0.8588230708590638, Best Loss: 0.8599089081030721, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 376/500, Loss: 0.8592618128411244, Best Loss: 0.8588230708590638, LR: 1e-05
# Epoch 377/500, Loss: 0.8601092832510058, Best Loss: 0.8588230708590638, LR: 1e-05
# Epoch 378/500, Loss: 0.8590057861531807, Best Loss: 0.8588230708590638, LR: 1e-05
# Epoch 379/500, Loss: 0.8586478172006207, Best Loss: 0.8588230708590638, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 380/500, Loss: 0.8579927526971658, Best Loss: 0.8586478172006207, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 381/500, Loss: 0.8588645140484613, Best Loss: 0.8579927526971658, LR: 1e-05
# Epoch 382/500, Loss: 0.8585346066173516, Best Loss: 0.8579927526971658, LR: 1e-05
# Epoch 383/500, Loss: 0.8571160527931062, Best Loss: 0.8579927526971658, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 384/500, Loss: 0.856993742232399, Best Loss: 0.8571160527931062, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 385/500, Loss: 0.8571927183590768, Best Loss: 0.856993742232399, LR: 1e-05
# Epoch 386/500, Loss: 0.8567086309774377, Best Loss: 0.856993742232399, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 387/500, Loss: 0.8569273486366222, Best Loss: 0.8567086309774377, LR: 1e-05
# Epoch 388/500, Loss: 0.8563526212988712, Best Loss: 0.8567086309774377, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 389/500, Loss: 0.8569422063763606, Best Loss: 0.8563526212988712, LR: 1e-05
# Epoch 390/500, Loss: 0.8563306659679107, Best Loss: 0.8563526212988712, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 391/500, Loss: 0.8555648893285406, Best Loss: 0.8563306659679107, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 392/500, Loss: 0.8549380700308886, Best Loss: 0.8555648893285406, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 393/500, Loss: 0.8548607174524537, Best Loss: 0.8549380700308886, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 394/500, Loss: 0.8542859135537862, Best Loss: 0.8548607174524537, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 395/500, Loss: 0.8545993812610925, Best Loss: 0.8542859135537862, LR: 1e-05
# Epoch 396/500, Loss: 0.8540729376283291, Best Loss: 0.8542859135537862, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 397/500, Loss: 0.8544038665846112, Best Loss: 0.8540729376283291, LR: 1e-05
# Epoch 398/500, Loss: 0.8545718178107942, Best Loss: 0.8540729376283291, LR: 1e-05
# Epoch 399/500, Loss: 0.8534123120347092, Best Loss: 0.8540729376283291, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 400/500, Loss: 0.8530453665401839, Best Loss: 0.8534123120347092, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 401/500, Loss: 0.8526891998743733, Best Loss: 0.8530453665401839, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 402/500, Loss: 0.8525353063508333, Best Loss: 0.8526891998743733, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 403/500, Loss: 0.8527807297770512, Best Loss: 0.8525353063508333, LR: 1e-05
# Epoch 404/500, Loss: 0.8525106697385568, Best Loss: 0.8525353063508333, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 405/500, Loss: 0.8518720278995562, Best Loss: 0.8525106697385568, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 406/500, Loss: 0.8515883720235499, Best Loss: 0.8518720278995562, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 407/500, Loss: 0.8515880394950863, Best Loss: 0.8515883720235499, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 408/500, Loss: 0.8512297319324822, Best Loss: 0.8515880394950863, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 409/500, Loss: 0.8511900904371374, Best Loss: 0.8512297319324822, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 410/500, Loss: 0.8510915753751722, Best Loss: 0.8511900904371374, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 411/500, Loss: 0.850142110723775, Best Loss: 0.8510915753751722, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 412/500, Loss: 0.8502476327717176, Best Loss: 0.850142110723775, LR: 1e-05
# Epoch 413/500, Loss: 0.8497839823101075, Best Loss: 0.850142110723775, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 414/500, Loss: 0.8502602741876001, Best Loss: 0.8497839823101075, LR: 1e-05
# Epoch 415/500, Loss: 0.8497716439940225, Best Loss: 0.8497839823101075, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 416/500, Loss: 0.8495632339183562, Best Loss: 0.8497716439940225, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 417/500, Loss: 0.8490396784952694, Best Loss: 0.8495632339183562, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 418/500, Loss: 0.8484610457519304, Best Loss: 0.8490396784952694, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 419/500, Loss: 0.8485930463837897, Best Loss: 0.8484610457519304, LR: 1e-05
# Epoch 420/500, Loss: 0.8483597347347756, Best Loss: 0.8484610457519304, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 421/500, Loss: 0.8484014655623249, Best Loss: 0.8483597347347756, LR: 1e-05
# Epoch 422/500, Loss: 0.8478540795940988, Best Loss: 0.8483597347347756, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 423/500, Loss: 0.8471220871920818, Best Loss: 0.8478540795940988, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 424/500, Loss: 0.8471547118317653, Best Loss: 0.8471220871920818, LR: 1e-05
# Epoch 425/500, Loss: 0.8469156681898606, Best Loss: 0.8471220871920818, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 426/500, Loss: 0.8468553356881066, Best Loss: 0.8469156681898606, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 427/500, Loss: 0.8465565531170322, Best Loss: 0.8468553356881066, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 428/500, Loss: 0.8464167832400549, Best Loss: 0.8465565531170322, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 429/500, Loss: 0.8460574740720321, Best Loss: 0.8464167832400549, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 430/500, Loss: 0.846455643432665, Best Loss: 0.8460574740720321, LR: 1e-05
# Epoch 431/500, Loss: 0.8473906776269071, Best Loss: 0.8460574740720321, LR: 1e-05
# Epoch 432/500, Loss: 0.8461078554069743, Best Loss: 0.8460574740720321, LR: 1e-05
# Epoch 433/500, Loss: 0.845777146547221, Best Loss: 0.8460574740720321, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 434/500, Loss: 0.8450922121024472, Best Loss: 0.845777146547221, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 435/500, Loss: 0.8453590754456609, Best Loss: 0.8450922121024472, LR: 1e-05
# Epoch 436/500, Loss: 0.8456615358784351, Best Loss: 0.8450922121024472, LR: 1e-05
# Epoch 437/500, Loss: 0.8456901622138083, Best Loss: 0.8450922121024472, LR: 1e-05
# Epoch 438/500, Loss: 0.8441962936045131, Best Loss: 0.8450922121024472, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 439/500, Loss: 0.8436406615282415, Best Loss: 0.8441962936045131, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 440/500, Loss: 0.8441939795888248, Best Loss: 0.8436406615282415, LR: 1e-05
# Epoch 441/500, Loss: 0.8444493542591628, Best Loss: 0.8436406615282415, LR: 1e-05
# Epoch 442/500, Loss: 0.843867952592745, Best Loss: 0.8436406615282415, LR: 1e-05
# Epoch 443/500, Loss: 0.8429830279692498, Best Loss: 0.8436406615282415, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 444/500, Loss: 0.8431749723455476, Best Loss: 0.8429830279692498, LR: 1e-05
# Epoch 445/500, Loss: 0.8433485416122911, Best Loss: 0.8429830279692498, LR: 1e-05
# Epoch 446/500, Loss: 0.8427418891454846, Best Loss: 0.8429830279692498, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 447/500, Loss: 0.8429424109213599, Best Loss: 0.8427418891454846, LR: 1e-05
# Epoch 448/500, Loss: 0.8424847511259757, Best Loss: 0.8427418891454846, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 449/500, Loss: 0.8430053668521051, Best Loss: 0.8424847511259757, LR: 1e-05
# Epoch 450/500, Loss: 0.8421684170872218, Best Loss: 0.8424847511259757, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 451/500, Loss: 0.8418424752848106, Best Loss: 0.8421684170872218, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 452/500, Loss: 0.8411705325652756, Best Loss: 0.8418424752848106, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 453/500, Loss: 0.8425960385124249, Best Loss: 0.8411705325652756, LR: 1e-05
# Epoch 454/500, Loss: 0.8415986612355405, Best Loss: 0.8411705325652756, LR: 1e-05
# Epoch 455/500, Loss: 0.8416528450272788, Best Loss: 0.8411705325652756, LR: 1e-05
# Epoch 456/500, Loss: 0.8410082986949586, Best Loss: 0.8411705325652756, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 457/500, Loss: 0.8402104872519249, Best Loss: 0.8410082986949586, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 458/500, Loss: 0.8403890668392388, Best Loss: 0.8402104872519249, LR: 1e-05
# Epoch 459/500, Loss: 0.8405293238869076, Best Loss: 0.8402104872519249, LR: 1e-05
# Epoch 460/500, Loss: 0.8398742711343036, Best Loss: 0.8402104872519249, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 461/500, Loss: 0.8399343757056282, Best Loss: 0.8398742711343036, LR: 1e-05
# Epoch 462/500, Loss: 0.8405447856616108, Best Loss: 0.8398742711343036, LR: 1e-05
# Epoch 463/500, Loss: 0.8395861277990511, Best Loss: 0.8398742711343036, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 464/500, Loss: 0.8393268352765002, Best Loss: 0.8395861277990511, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 465/500, Loss: 0.8385577888855726, Best Loss: 0.8393268352765002, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 466/500, Loss: 0.8393310606093104, Best Loss: 0.8385577888855726, LR: 1e-05
# Epoch 467/500, Loss: 0.8389129184872569, Best Loss: 0.8385577888855726, LR: 1e-05
# Epoch 468/500, Loss: 0.8379684449582196, Best Loss: 0.8385577888855726, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 469/500, Loss: 0.8379525609001988, Best Loss: 0.8379684449582196, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 470/500, Loss: 0.8378338433167556, Best Loss: 0.8379525609001988, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 471/500, Loss: 0.8375076728366022, Best Loss: 0.8378338433167556, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 472/500, Loss: 0.8378449650332364, Best Loss: 0.8375076728366022, LR: 1e-05
# Epoch 473/500, Loss: 0.838587336425806, Best Loss: 0.8375076728366022, LR: 1e-05
# Epoch 474/500, Loss: 0.8370184603574418, Best Loss: 0.8375076728366022, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 475/500, Loss: 0.8360812272336954, Best Loss: 0.8370184603574418, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 476/500, Loss: 0.8362206217019114, Best Loss: 0.8360812272336954, LR: 1e-05
# Epoch 477/500, Loss: 0.8364324938462402, Best Loss: 0.8360812272336954, LR: 1e-05
# Epoch 478/500, Loss: 0.8358801168587318, Best Loss: 0.8360812272336954, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 479/500, Loss: 0.8362007842041227, Best Loss: 0.8358801168587318, LR: 1e-05
# Epoch 480/500, Loss: 0.8355531017088653, Best Loss: 0.8358801168587318, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 481/500, Loss: 0.8355727530999767, Best Loss: 0.8355531017088653, LR: 1e-05
# Epoch 482/500, Loss: 0.8359341964647464, Best Loss: 0.8355531017088653, LR: 1e-05
# Epoch 483/500, Loss: 0.8357637371792197, Best Loss: 0.8355531017088653, LR: 1e-05
# Epoch 484/500, Loss: 0.8351269215925194, Best Loss: 0.8355531017088653, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 485/500, Loss: 0.8347299058252838, Best Loss: 0.8351269215925194, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 486/500, Loss: 0.8344365361444991, Best Loss: 0.8347299058252838, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 487/500, Loss: 0.8340227255252239, Best Loss: 0.8344365361444991, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 488/500, Loss: 0.833826873527169, Best Loss: 0.8340227255252239, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 489/500, Loss: 0.835041583460541, Best Loss: 0.833826873527169, LR: 1e-05
# Epoch 490/500, Loss: 0.8339944504011363, Best Loss: 0.833826873527169, LR: 1e-05
# Epoch 491/500, Loss: 0.8330206329617416, Best Loss: 0.833826873527169, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 492/500, Loss: 0.8337378722993626, Best Loss: 0.8330206329617416, LR: 1e-05
# Epoch 493/500, Loss: 0.8328676769808676, Best Loss: 0.8330206329617416, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 494/500, Loss: 0.8327221086516918, Best Loss: 0.8328676769808676, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 495/500, Loss: 0.8333749122244426, Best Loss: 0.8327221086516918, LR: 1e-05
# Epoch 496/500, Loss: 0.8330438159731524, Best Loss: 0.8327221086516918, LR: 1e-05
# Epoch 497/500, Loss: 0.832089825440319, Best Loss: 0.8327221086516918, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 498/500, Loss: 0.832734302710621, Best Loss: 0.832089825440319, LR: 1e-05
# Epoch 499/500, Loss: 0.8319545242109188, Best Loss: 0.832089825440319, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth
# Epoch 500/500, Loss: 0.8315808514831285, Best Loss: 0.8319545242109188, LR: 1e-05
# Saved best model to MLP_15to1_s32_multi_3.pth

# %%
X_train_tensor = torch.from_numpy(model_class.X_train[0:10]).to(model_class.device)
F_train_tensor = torch.from_numpy(model_class.F_train[0:10]).to(model_class.device)
print('Input tensor shape: ', X_train_tensor.shape, F_train_tensor.shape)

# model_class.model.to(model_class.device)
# model_class.load_model('MLP_15to1_s32.pth')
prediction = model_class.model(X_train_tensor, F_train_tensor) 


print('Output tensor shape: ', prediction.shape)
# Out:
# Input tensor shape:  torch.Size([10, 15, 16, 32]) torch.Size([10, 2])
# Output tensor shape:  torch.Size([10, 1, 16, 32])

# %%
seed = 50 

model_class.plot_pred_target(seed=seed, frame_rate=8, levels=10)
# Out:
# C:\Users\23603526\AppData\Local\Temp\ipykernel_24336\1106014529.py:494: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   F = torch.tensor(F).float()
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5a67109982a24e2d8e366f45fbeb66c7">
#   <div class="anim-controls">
#     <input id="_anim_slider5a67109982a24e2d8e366f45fbeb66c7" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5a67109982a24e2d8e366f45fbeb66c7.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim5a67109982a24e2d8e366f45fbeb66c7.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select5a67109982a24e2d8e366f45fbeb66c7"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5a67109982a24e2d8e366f45fbeb66c7"
#              >
#       <label for="_anim_radio1_5a67109982a24e2d8e366f45fbeb66c7">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5a67109982a24e2d8e366f45fbeb66c7"
#              checked>
#       <label for="_anim_radio2_5a67109982a24e2d8e366f45fbeb66c7">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5a67109982a24e2d8e366f45fbeb66c7"
#              >
#       <label for="_anim_radio3_5a67109982a24e2d8e366f45fbeb66c7">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5a67109982a24e2d8e366f45fbeb66c7";
#     var slider_id = "_anim_slider5a67109982a24e2d8e366f45fbeb66c7";
#     var loop_select_id = "_anim_loop_select5a67109982a24e2d8e366f45fbeb66c7";
#     var frames = new Array(13);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAEAAElEQ

# %%
model_class.prediction_plots(seed=seed)
# Out:
# C:\Users\23603526\AppData\Local\Temp\ipykernel_24336\1106014529.py:494: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   F = torch.tensor(F).float()
